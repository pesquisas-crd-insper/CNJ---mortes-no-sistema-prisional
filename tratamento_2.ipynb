# %%
import pandas as pd
import re, os
import numpy as np
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df =  pd.read_excel("/content/drive/My Drive/codigos_colab/df_final_est.xlsx")

# %%
pd.set_option('display.max_rows', None)

df_tratadas = pd.DataFrame()
# var_5 = df.loc[:,'5 - É caso de interesse?'].to_list()

# df_tratadas['5 - É caso de interesse?'] = var_5

# print(df_tratadas)

# %% [markdown]
# ## 1. Variável 47

# %%
dict_47 = {
    '1': 'ilegível',
    '2': 'SI',
    '3':'não se aplica',
    '4':'médico legista',
    '5':'medico assistente',
    '6':'médico substituto',
    '7':'Serviço de verificação de óbito'
}

cod_47 = pd.read_excel("/content/drive/My Drive/codigos_colab/responsavel_obito_47.xlsx")


var_47 = df.loc[:,'47 - Responsável pela emissão da Declaração de Óbito (D.O.) ou Atestado de Óbito']

var_47_trata = []
for i in range(len(var_47)):
  vl_v = var_47[i]
  cont = "Não"
  for j in range(len(cod_47)):
    vl_c = cod_47.iloc[j,1]
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_47.iloc[j,0])
      # print(dict_47[a])
      var_47_trata.append(dict_47[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_47_trata.append(None)

print(len(var_47_trata))
print(len(var_47))

df ["47- codificada"] = var_47_trata
df_tratadas ["47- codificada"] = var_47_trata

# print(df ["47- codificada"])
# Out:
# 4011
# 4011

# %% [markdown]
# ## 2. Variável 70

# %%
dict_var = {
    '1': 'morte por arma de fogo',
    '2': 'reconhecimento do corpo',
    '3':'suspeita de irregularidade funcional',
    '4':'morte violenta por meio insidioso e/ou cruel',
    '5':'morte violenta',
    '6':'homicidio',
    '7':'morte por suspeita de violência policial',
    '8':'morte em unidade de detenção ou estabelecimento prisional',
    '9':'morte sem maiores especificações',
    '10':'NSA',
    '11':'SI'
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/motivo_pericia_70.xlsx")


dados_var = df.loc[:,'70 - Qual foi o motivo de requisição da perícia?']

var_70_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,0] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,3]) # codigo atribuido
      # print(dict_47[a])
      var_70_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_70_trata.append(None)

print(len(var_70_trata))
print(len(dados_var))

df ["70- codificada"] = var_70_trata
df_tratadas ["70- codificada"] = var_70_trata

# print(df ["70- codificada"] )
# Out:
# 4011
# 4011

# %% [markdown]
# ## 3. Variável 51

# %%
dict_var = {
    '1': 'área rural, floresta, ou mata',
    '2': 'complexo médico penal, hospital de custodia ou de tratamento psiquiátrico',
    '3':'domicilio',
    '4':'em trânsito',
    '5':'estabelecimento comercial',
    '6':'estabelecimento religioso',
    '7':'rios, mares, lagos, ou qualquer ponto de água natural',
    '8':'rua',
    '9':'SI',
    '10':'sítio, chácara, ou propriedade rural',
    '11':'unidade de detenção provisória',
    '12':'unidade de internação socioeducativa',
    '13':'unidade de regime fechado',
    '14':'unidade de saúde',
    '15':'unidade de semiaberto',
    '16':'unidade prisional não especificada'
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/local_obito_51.xlsx")


dados_var = df.loc[:,'51 - Onde ocorreu o óbito? (Unidade prisional, unidade de saúde ou na rua)']

var_51_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,0] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,3]) # codigo atribuido
      # print(dict_47[a])
      var_51_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_51_trata.append(None)

print(len(var_51_trata))
print(len(dados_var))

df ["51 - codificada"] = var_51_trata

df_tratadas["51 - codificada"] = var_51_trata

print(df ["51 - codificada"])
# Out:
# 4011
# 4011
# 0                                        unidade de saúde
# 1                                                     rua
# 2                               unidade de regime fechado
# 3                                                     rua
# 4                                                     rua
# 5                                               domicilio
# 6                                                     rua
# 7                           área rural, floresta, ou mata
# 8                                                     rua
# 9                                                     rua
# 10                                                    rua
# 11                                                     SI
# 12                                              domicilio
# 13                                       unidade de saúde
# 14                                       unidade de saúde
# 15                                                    rua
# ...

# %% [markdown]
# ## 4. Variável 73

# %%
dict_var = {
    '1': 'NSA',
    '2': 'SI',
    '3':'a esclarecer por exames',
    '4':'possível violência policial'
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/mudanca_causa_morte_73.xlsx")


dados_var = df.loc[:,'73 - Explicação sobre mudança de causa da morte']

var_73_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,1] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,0]) # codigo atribuido
      # print(dict_47[a])
      var_73_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_73_trata.append(None)

print(len(var_73_trata))
print(len(dados_var))

df ["73 - codificada"] = var_73_trata
df_tratadas["73 - codificada"] = var_73_trata

print(df ["73 - codificada"])
# Out:
# 4011
# 4011
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# 5                              None
# 6                              None
# 7                              None
# 8                              None
# 9                              None
# 10                             None
# 11                             None
# 12                             None
# 13                             None
# 14                             None
# 15                             None
# 16                             None
# 17                             None
# 18                             None
# 19                             None
# 20                             None
# 21                             None
# 22                             None
# 23                             None
# 24                             None
# ...

# %% [markdown]
# ## 5. Variável 38 (Tem um problema com a categoria 8, que se mistura com a 4 e a 11. Manu disse que foi um erro da coleta. Vamos justificar no questionário)

# %%
dict_var = {
    '1': 'foragido',
    '2': 'liberdade provisória',
    '3':'pena restritiva de direitos',
    '4':'regime aberto',
    '5':'prisão em flagrante',
    '6': 'Prisão domiciliar',
    '7': 'cumprindo pena privativa de liberdade',
    '8': 'semiaberto ou aberto na rua com tornozeleira eletrônica',
    '9': 'em livramento condicional',
    '10': 'sem informações',
    '11': 'semiaberto',
    '12': 'outros'
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/regime_vigilancia_38.xlsx")


dados_var = df.loc[:,'38 - Em que regime ou sob que mecanismos de vigilância estava a pessoa na data da morte?']

var_38_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,1] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,0]) # codigo atribuido
      # print(dict_47[a])
      var_38_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_38_trata.append(None)

print(len(var_38_trata))
print(len(dados_var))

df ["38 - codificada"] = var_38_trata

df_tratadas["38 - codificada"] = var_38_trata

print(df ["38 - codificada"])
# Out:
# 4011
# 4011
# 0       semiaberto ou aberto na rua com tornozeleira e...
# 1                                              semiaberto
# 2                   cumprindo pena privativa de liberdade
# 3       semiaberto ou aberto na rua com tornozeleira e...
# 4                                    liberdade provisória
# 5                                           regime aberto
# 6                                    liberdade provisória
# 7                                           regime aberto
# 8                                    liberdade provisória
# 9                                                  outros
# 10                                    prisão em flagrante
# 11                                          regime aberto
# 12                                   liberdade provisória
# 13                                   liberdade provisória
# 14                                          regime aberto
# 15                                          regime aberto
# ...

# %% [markdown]
# ## 6. Variável 42

# %%
dict_var = {
    '1': 'oficial de justiça',
    '2': 'judiciário',
    '3':'instituição de gestão ou controle prisional',
    '4':'central de monitoramento eletrônico',
    '5':'polícia',
    '6': 'familiar',
    '7': 'Secretarias estaduais ou municipais',
    '8': 'sem informações',
    '9':'ministério público',
    '10':'defesa particular',
    '11':'defensoria',
    '12':'outros'
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/informou_morte_42.xlsx")


dados_var = df.loc[:,'42 - Quem informou a morte no processo judicial ou no inquérito policial ?']

var_42_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,1] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,0]) # codigo atribuido
      # print(dict_47[a])
      var_42_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_42_trata.append(None)

print(len(var_42_trata))
print(len(dados_var))

df ["42 - codificada"] = var_42_trata

df_tratadas["42 - codificada"] = var_42_trata

print(df ["42 - codificada"])
# Out:
# 4011
# 4011
# 0               central de monitoramento eletrônico
# 1                                          familiar
# 2       instituição de gestão ou controle prisional
# 3       instituição de gestão ou controle prisional
# 4                                ministério público
# 5                                   sem informações
# 6                                        judiciário
# 7                                   sem informações
# 8                                   sem informações
# 9                                oficial de justiça
# 10                                          polícia
# 11                                  sem informações
# 12                                  sem informações
# 13                                         familiar
# 14                               oficial de justiça
# 15                                       judiciário
# 16              Secretarias estaduais ou municipais
# 17      instituição de gestão ou controle prisional
# ...

# %% [markdown]
# ## 7. Variável 64

# %%
dict_var = {
    '1': 'não se aplica',
    '2': 'polícia',
    '3':'sem informações',
    '4':'defensoria',
    '5':'juiz',
    '6': 'administração penitenciária',
    '7': 'impossível determinar'
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/proced_investig_64.xlsx")


dados_var = df.loc[:,'64 - Responsável por iniciar o procedimento investigativo']

var_64_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,1] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,0]) # codigo atribuido
      # print(dict_47[a])
      var_64_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_64_trata.append(None)

print(len(var_64_trata))
print(len(dados_var))

df ["64 - codificada"] = var_64_trata
df_tratadas["64 - codificada"] = var_64_trata

print(df ["64 - codificada"])
# Out:
# 4011
# 4011
# 0                     não se aplica
# 1                     não se aplica
# 2       administração penitenciária
# 3                           polícia
# 4                           polícia
# 5                     não se aplica
# 6                     não se aplica
# 7                     não se aplica
# 8                     não se aplica
# 9                     não se aplica
# 10                    não se aplica
# 11                    não se aplica
# 12                    não se aplica
# 13                    não se aplica
# 14                    não se aplica
# 15                    não se aplica
# 16                    não se aplica
# 17      administração penitenciária
# 18                    não se aplica
# 19                    não se aplica
# 20                    não se aplica
# 21            impossível determinar
# 22                    não se aplica
# 23                    não se aplica
# 24                    não se aplica
# ...

# %% [markdown]
# ## 8. Variável 25

# %%
dict_var = {
    "1":"sem ocupação",
    "2":"sem informação",
    "3":"autônomo",
    "4":"pedreiro ou ajudante de pedreiro",
    "5":"agricultor",
    "6":"marceneiro ou ajudante de marcenaria",
    "7":"mecânico",
    "8":"serviços gerais",
    "9":"técnico de enfermagem",
    "10":"lavrador",
    "11":"pintor",
    "12":"vendedor",
    "13":"comerciante",
    "14":"motorista",
    "15":"servente",
    "16":"trabalhador Rural",
    "17":"policial Militar",
    "18":"açougueiro",
    "19":"borracheiro",
    "20":"mototaxista",
    "21":"eletricista",
    "22":"diarista ou empregada Doméstica",
    "23":"frentista",
    "24":"lavador de veículos",
    "25":"soldador",
    "26":"pescador",
    "27":"carpinteiro",
    # "28":"trocada pelo 8"
    "29":"porteiro",
    "30":"empresário",
    "31":"encanador",
    "32":"dona de casa",
    "33":"cozinheira",
    "34":"feirante",
    "35":"garçom",
    "36":"músico",
    "37":"carregador",
    "38":"cobrador de ônibus",
    "39":"segurança",
    "40":"artesão",
    "41":"motoboy",
    "42":"barbeiro",
    "43":"vaqueiro",
    "44":"professor",
    "45":"estudante",
    "46":"reciclador",
    "47":"flanelinha",
    "48":"advogado",
    "49":"corretor de imóveis",
    "50":"padeiro",
    "51":"montador",
    "52":"serralheiro",
    "53":"estofador",
    "54":"liderança do tráfico",
    "55":"Servidor",
    "56":"tesoureiro ou contador",
    "57":"múltiplas ocupações",
    "58":"outros",
    "59": "Médico"
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/ocupacao_25.xlsx")


dados_var = df.loc[:,'25 - Ocupação laborativa fora do cárcere (se não houver colocar "NSA")']

# print(dados_var)

# z= input("")

var_25_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,1] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,0]) # codigo atribuido
      # print(dict_47[a])
      var_25_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_25_trata.append(None)

print(len(var_25_trata))
print(len(dados_var))

df ["25 - codificada"] = var_25_trata
df_tratadas["25 - codificada"] = var_25_trata

print(df ["25 - codificada"])
# Out:
# 4011
# 4011
# 0                               sem ocupação
# 1                                       None
# 2                               sem ocupação
# 3                                       None
# 4                                       None
# 5                                       None
# 6           pedreiro ou ajudante de pedreiro
# 7                                 agricultor
# 8                                       None
# 9            diarista ou empregada Doméstica
# 10                              sem ocupação
# 11                              sem ocupação
# 12                            sem informação
# 13                            sem informação
# 14                           serviços gerais
# 15                            sem informação
# 16                              sem ocupação
# 17                              sem ocupação
# 18                              sem ocupação
# 19                              sem ocupação
# ...

# %% [markdown]
# ## 9. Variável 41

# %%
dict_var = {
    '1': 'prisão definitiva',
    '2': 'não se aplica',
    '3':'prisão pós-condenação',
    '4':'prisão pré-condenação',
    '5':'SI',
    '6': None
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/tipo_custodia_morte_41.xlsx")


dados_var = df.loc[:,'41 - Caso a pessoa estivesse presa no momento da morte: a pessoa presa estava cumprindo pena decorrente de sentença transitada em julgado ou se preso processualmente?']

var_41_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,1] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,0]) # codigo atribuido
      # print(dict_47[a])
      var_41_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_41_trata.append(None)

print(len(var_41_trata))
print(len(dados_var))

df ["41 - codificada"] = var_41_trata
df_tratadas["41 - codificada"] = var_41_trata

print(df ["41 - codificada"])
# Out:
# 4011
# 4011
# 0               não se aplica
# 1               não se aplica
# 2           prisão definitiva
# 3               não se aplica
# 4               não se aplica
# 5               não se aplica
# 6               não se aplica
# 7               não se aplica
# 8               não se aplica
# 9               não se aplica
# 10              não se aplica
# 11              não se aplica
# 12              não se aplica
# 13              não se aplica
# 14              não se aplica
# 15              não se aplica
# 16              não se aplica
# 17      prisão pré-condenação
# 18              não se aplica
# 19              não se aplica
# 20              não se aplica
# 21              não se aplica
# 22              não se aplica
# 23              não se aplica
# 24      prisão pós-condenação
# 25              não se aplica
# 26              não se aplica
# 27                         SI
# 28              não se aplica
# 29              não se aplica
# ...

# %% [markdown]
# ## 10. Variável 24

# %%
dict_var = {
    '1': 'desempregado',
    '2': 'autônomo',
    '3':'sem informações',
    '4':'estudante',
    '5':'aposentado/a',
    '6': 'Dona de casa',
    '7': 'pensionista',
    '8': 'policial militar',
    '9':'outros'
}

cod_var = pd.read_excel("/content/drive/My Drive/codigos_colab/profissao_24.xlsx")


dados_var = df.loc[:,'24 - Profissão']

var_24_trata = []
for i in range(len(dados_var)):
  vl_v = dados_var[i]
  cont = "Não"
  for j in range(len(cod_var)):
    vl_c = cod_var.iloc[j,1] # nome como aparece no banco
    if vl_v == vl_c:
      # print(cod_47.iloc[j,0])
      a = str(cod_var.iloc[j,0]) # codigo atribuido
      # print(dict_47[a])
      var_24_trata.append(dict_var[a])
      cont = "Sim"
      break
  if cont != "Sim":
    var_24_trata.append(None)

print(len(var_24_trata))
print(len(dados_var))

df ["24 - codificada"] = var_24_trata
df_tratadas["24 - codificada"] = var_24_trata

print(df ["24 - codificada"])
# Out:
# 4011
# 4011
# 0           desempregado
# 1           desempregado
# 2        sem informações
# 3           desempregado
# 4        sem informações
# 5        sem informações
# 6               autônomo
# 7               autônomo
# 8              estudante
# 9               autônomo
# 10          desempregado
# 11       sem informações
# 12          desempregado
# 13       sem informações
# 14              autônomo
# 15       sem informações
# 16          desempregado
# 17       sem informações
# 18       sem informações
# 19       sem informações
# 20             estudante
# 21       sem informações
# 22       sem informações
# 23              autônomo
# 24          desempregado
# 25       sem informações
# 26              autônomo
# 27          desempregado
# 28              autônomo
# 29       sem informações
# 30       sem informações
# 31             estudante
# 32       sem informações
# 33              autônomo
# 34       sem informações
# 35              autônomo
# ...

# %%
# df_tratadas.to_excel("variaveis_codificadas.xlsx", index = False)
# files.download('variaveis_codificadas.xlsx')

# %% [markdown]
# ## Transformando as variáveis tratadas em uma planilha para gerar os gráficos e unificando com o banco tratado para gerar a versão final

# %%
df_final_ajust = pd.concat([df, df_tratadas], axis = 1)

# %%
df_final_ajust.to_excel("df_final_ajust.xlsx", index = False)
files.download('df_final_ajust.xlsx')
