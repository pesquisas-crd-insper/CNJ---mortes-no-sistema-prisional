# %%
import pandas as pd
import re, os
import numpy as np
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator

! pip install docxtpl
from docxtpl import DocxTemplate, InlineImage
from docx.shared import Cm
import matplotlib.pyplot as plt
import datetime
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting docxtpl
#   Downloading docxtpl-0.16.4-py2.py3-none-any.whl (28 kB)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 7.9 MB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from docxtpl) (4.9.1)
# Collecting docxcompose
#   Downloading docxcompose-1.3.7.tar.gz (19 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from docxtpl) (2.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from docxtpl) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from docxcompose->docxtpl) (57.4.0)
# Requirement already satisfied: babel in /usr/local/lib/python3.8/dist-packages (from docxcompose->docxtpl) (2.11.0)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.8/dist-packages (from babel->docxcompose->docxtpl) (2022.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->docxtpl) (2.0.1)
# Building wheels for collected packages: docxcompose, python-docx
#   Building wheel for docxcompose (setup.py) ... done
#   Created wheel for docxcompose: filename=docxcompose-1.3.7-py3-none-any.whl size=22441 sha256=9fefa611c5543706f5f606d8575823c23578b092edc5236a3a6dd4658c66c050
#   Stored in directory: /root/.cache/pip/wheels/bf/c3/e4/e46bf4bb79f3ec7dd616ea74c41983e9794ec677907d77fc88
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184505 sha256=c5a3fe66675f2fa843e4a7ca3bf84fa384ea2dd502cbbebc48fff3d408dd62e9
#   Stored in directory: /root/.cache/pip/wheels/32/b8/b2/c4c2b95765e615fe139b0b17b5ea7c0e1b6519b0a9ec8fb34d
# Successfully built docxcompose python-docx
# Installing collected packages: python-docx, docxcompose, docxtpl
# Successfully installed docxcompose-1.3.7 docxtpl-0.16.4 python-docx-0.8.11

# %%
df_final = pd.read_excel("/content/drive/My Drive/codigos_colab/planilha_coleta_30_11.xlsx")
print(df_final)
df_final = df_final.iloc[5:,:]
# Out:
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 0    2022-05-12 15:31:25.382                   Saylon
# 1    2022-05-12 15:36:54.442                   Saylon
# 2    2022-05-12 15:40:41.812                   saylon
# 3    2022-05-12 15:41:30.038                 Saylon 2
# 4    2022-05-12 15:57:28.137                   saylon
# ...                      ...                      ...
# 3997 2022-11-24 21:14:32.273            Manuela Abath
# 3998 2022-11-24 21:16:23.077            Manuela Abath
# 3999 2022-11-24 21:17:16.389            Manuela Abath
# 4000 2022-11-29 15:45:01.549            Manuela Abath
# 4001 2022-11-29 15:49:50.961            Manuela Abath
#
#      2 - início do preenchimento  \
# 0                       15:30:00
# 1                       15:36:00
# 2                       15:37:00
# 3                       15:40:00
# 4                       15:56:00
# ...                          ...
# 3997                         NaN
# 3998                         NaN
# 3999                         NaN
# 4000                         NaN
# 4001                         NaN
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                          0000198-53.2020.8.21.0106
# 3998                          0011477-19.2019.8.21.0026
# 3999                          0011715-03.2017.8.21.0028
# 4000                          0134343-20.2019.8.09.0137
# 4001                          0006547-68.2019.8.09.0162
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
# 4000                                                NaN
# 4001                                                NaN
#
#      5 - É caso de interesse?  \
# 0          sim: morte interna
# 1                         não
# 2                         não
# 3                         não
# 4                         não
# ...                       ...
# 3997                      não
# 3998                      não
# 3999                      não
# 4000                      não
# 4001                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
# 4000                                                NaN
# 4001                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
# 4000                                                NaN
# 4001                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
# 4000                                                NaN
# 4001                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
# 4000                                                NaN
# 4001                                                NaN
#
#       ... 80 - fim do preenchimento  \
# 0     ...                  15:31:00
# 1     ...                  15:37:00
# 2     ...                  15:38:00
# 3     ...                  15:41:00
# 4     ...                  15:57:00
# ...   ...                       ...
# 3997  ...                       NaN
# 3998  ...                       NaN
# 3999  ...                       NaN
# 4000  ...                       NaN
# 4001  ...                       NaN
#
#                                     URL do questionário  \
# 0                                                   NaN
# 1                                                   NaN
# 2                   https://forms.gle/n8SstxUqAhnyvmhE8
# 3     https://docs.google.com/forms/d/e/1FAIpQLSfNOy...
# 4                                        wwwwwwwwwwwwww
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
# 4000                                                NaN
# 4001                                                NaN
#
#             Endereço de e-mail  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4     saylon.pereira@gmail.com
# ...                        ...
# 3997   manuela.valenca@ufpe.br
# 3998   manuela.valenca@ufpe.br
# 3999   manuela.valenca@ufpe.br
# 4000   manuela.valenca@ufpe.br
# 4001   manuela.valenca@ufpe.br
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                    Processo físico
# 3998                                    Processo físico
# 3999                                    Processo físico
# 4000                      Pessoa não passou pela prisão
# 4001                      Pessoa não passou pela prisão
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                Sim
# 4000                                                Não
# 4001                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
# 4000                                                NaN
# 4001                                                NaN
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 0                                               NaN         NaN
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                               NaN         NaN
# 4                                               NaN         NaN
# ...                                             ...         ...
# 3997                                            NaN         NaN
# 3998                                            NaN         NaN
# 3999                                            NaN         NaN
# 4000                                            NaN         NaN
# 4001                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 3997                                       NaN
# 3998                                       NaN
# 3999                                       NaN
# 4000                                       NaN
# 4001                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
# 4000                                                NaN
# 4001                                                NaN
#
# [4002 rows x 91 columns]

# %%
# limpando os números
numeros = df_final.iloc[:,3].to_list()


rgx_lp = re.compile("[^0-9]")

nm_limpos = []
for n in range(len(numeros)):
    print(numeros[n])
    nm = re.sub(rgx_lp,"",numeros[n])
    # print(nm.strip())
    nm_limpos.append(nm.strip())

print(len(nm_limpos))

# %%
# inserindo os Estados

dic_estados = {"801": "AC",
               "802": "AL",
               "803": "AP",
               "804": "AM",
               "805": "BA",
               "806": "CE",
               "807": "DF",
               "808": "ES",
               "809": "GO",
               "810": "MA",
               "811": "MT",
               "812": "MS",
               "813": "MG",
               "814": "PA",
               "815": "PB",
               "816": "PR",
               "817": "PE",
               "818": "PI",
               "819": "RJ",
               "820": "RN",
               "821": "RS",
               "822": "RO",
               "823": "RR",
               "824": "SC",
               "825": "SE",
               "826": "SP",
               "827": "TO",
               "501": "TRF1"
              }


# teste = "00021646120198060055"
#print(teste[13:16])

estados = []
a =0
for num in nm_limpos:
  trecho = num[13:16]
  try:
    estados.append(dic_estados[trecho])
  except:
    estados.append(None)
    a = a+1

# print(a)


df_final["Estado"] = estados


df_final["Estado"] = np.where(df_final["Estado"].isnull() == True, df_final["9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído"].str[2:],df_final["Estado"])

print(df_final["Estado"])
# Out:
# 5       AC
# 6       AC
# 7       AC
# 8       AC
# 9       AC
#         ..
# 3997    RS
# 3998    RS
# 3999    RS
# 4000    GO
# 4001    GO
# Name: Estado, Length: 3997, dtype: object

# %%
# 1 - AC

filter_ac = df_final["Estado"] == "AC"
df_filt_ac = df_final[filter_ac]

print(df_filt_ac.value_counts(subset = ['Endereço de e-mail']))

filter_2_ac = df_filt_ac['Endereço de e-mail'] == "anandaendo@usp.br"
df_filt_ac_dv = df_filt_ac[filter_2_ac]


# print(df_filt_ac_dv)
# Out:
# Endereço de e-mail
# manuela.valenca@ufpe.br      132
# anandaendo@usp.br              6
# anandaendo@gmail.com           1
# manuela.valenca@gmail.com      1
# dtype: int64

# %%
# 2- AL

filter_al = df_final["Estado"] == "AL"
df_filt_al = df_final[filter_al]

print(df_filt_al.value_counts(subset = ['Endereço de e-mail']))


filter_2_al = df_filt_al['Endereço de e-mail'] == "anaclaraklink@gmail.com"
df_filt_al_dv = df_filt_al[filter_2_al]

# print(df_filt_al_dv)
# Out:
# Endereço de e-mail
# marimzambom@gmail.com      74
# anaclaraklink@gmail.com     6
# dtype: int64

# %%
# 3- AP

filter_ap = df_final["Estado"] == "AP"
df_filt_ap = df_final[filter_ap]

print(df_filt_ap.value_counts(subset = ['Endereço de e-mail']))


filter_2_ap = df_filt_ap['Endereço de e-mail'] == "anaclaraklink@gmail.com"
df_filt_ap_dv = df_filt_ap[filter_2_ap]

# print(df_filt_ap_dv)
# Out:
# Endereço de e-mail
# marimzambom@gmail.com      100
# anaclaraklink@gmail.com      6
# marimzambom@hotmail.com      1
# dtype: int64

# %%
# 4- AM

filter_am = df_final["Estado"] == "AM"
df_filt_am = df_final[filter_am]

print(df_filt_am.value_counts(subset = ['Endereço de e-mail']))


filter_2_am = df_filt_am['Endereço de e-mail'] == "anaclaraklink@gmail.com"
df_filt_am_dv = df_filt_am[filter_2_am]

print(df_filt_am_dv)
# Out:
# Endereço de e-mail
# manuela.valenca@ufpe.br    143
# anaclaraklink@gmail.com      6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 1081 2022-07-27 06:25:53.346                Ana Clara
# 1082 2022-07-27 06:27:10.501                Ana Clara
# 1083 2022-07-27 06:32:21.466                Ana Clara
# 1084 2022-07-27 07:04:55.091                Ana Clara
# 1085 2022-07-27 07:23:29.624                Ana Clara
# 1086 2022-07-27 08:30:54.502                Ana Clara
#
#      2 - início do preenchimento  \
# 1081                    06:25:00
# 1082                    06:26:00
# 1083                    06:27:00
# 1084                    06:33:00
# 1085                    07:05:00
# 1086                    07:45:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 1081                          0614940-03.2018.8.04.0001
# 1082                          0000444-27.2018.8.04.6400
# 1083                          0237061-27.2017.8.04.0001
# 1084                           242577-28.2017.8.04.0001
# 1085                          0000370-42.2020.8.04.3800
# 1086                           204976-17.2019.8.04.0001
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 1081                                2018-04-13 00:00:00
# 1082                                2018-08-20 00:00:00
# 1083                                2017-09-22 00:00:00
# 1084                                2017-10-30 00:00:00
# 1085                                2020-05-06 00:00:00
# 1086                                2019-02-13 00:00:00
#
#                                5 - É caso de interesse?  \
# 1081                                                não
# 1082                                                não
# 1083                                                não
# 1084                                 sim: morte externa
# 1085  não determinado (utilizar essa variável em cas...
# 1086                                 sim: morte interna
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                              E-SAJ
# 1085                                            PROJUDI
# 1086                                              E-SAJ
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                2.0
# 1085                                                2.0
# 1086                                                2.0
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                1.0
# 1085                                                1.0
# 1086                                                1.0
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                               TJAM
# 1085                                               TJAM
# 1086                                               TJAM
#
#       ... URL do questionário       Endereço de e-mail  \
# 1081  ...                 NaN  anaclaraklink@gmail.com
# 1082  ...                 NaN  anaclaraklink@gmail.com
# 1083  ...                 NaN  anaclaraklink@gmail.com
# 1084  ...                 NaN  anaclaraklink@gmail.com
# 1085  ...                 NaN  anaclaraklink@gmail.com
# 1086  ...                 NaN  anaclaraklink@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 1081  Processo digital, encontrado, mas sob restriçã...
# 1082  Processo digital, encontrado, mas sob restriçã...
# 1083                      Pessoa não passou pela prisão
# 1084                                      não se aplica
# 1085                                      não se aplica
# 1086                                      não se aplica
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 1081                                                Não
# 1082                                                Não
# 1083                                                Não
# 1084                                                Não
# 1085                                                Não
# 1086                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 1081                                                NSA
# 1082                                                NSA
# 1083                                                NSA
# 1084                                                NSA
# 1085                                                NSA
# 1086                                                NSA
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 1081                                            NaN         NaN
# 1082                                            NaN         NaN
# 1083                                            NaN         NaN
# 1084                                         Manaus         NaN
# 1085                                          Coari         NaN
# 1086                                         Manaus         NaN
#
#               5.2. O evento "prisão do agente" ocorreu:  \
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084              apenas no curso do processo analisado
# 1085  apenas em outro(s) processo(s) - relatado no p...
# 1086                                              ambos
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                NSA
# 1085                                                 SI
# 1086                           000579-19.2016.8.04.6300
#
#      Estado
# 1081     AM
# 1082     AM
# 1083     AM
# 1084     AM
# 1085     AM
# 1086     AM
#
# [6 rows x 92 columns]

# %%
# 5 - BA

filter_ba = df_final["Estado"] == "BA"
df_filt_ba = df_final[filter_ba]

print(df_filt_ba.value_counts(subset = ['Endereço de e-mail']))


filter_2_ba = df_filt_ba['Endereço de e-mail'] == "anaclaraklink@gmail.com"
df_filt_ba_dv = df_filt_ba[filter_2_ba]

print(df_filt_ba_dv)
# Out:
# Endereço de e-mail
# analiagalvaoalmeida12@gmail.com    251
# anaclaraklink@gmail.com              6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 1140 2022-07-29 11:14:19.133                Ana Clara
# 1141 2022-07-29 11:23:02.388                Ana Clara
# 1159 2022-08-01 08:24:47.168                Ana Clara
# 1160 2022-08-01 09:03:14.234                Ana Clara
# 1162 2022-08-01 10:00:33.400                Ana Clara
# 1163 2022-08-01 10:06:31.094                Ana Clara
#
#      2 - início do preenchimento  \
# 1140                    10:37:00
# 1141                    11:22:00
# 1159                    08:22:00
# 1160                    08:27:00
# 1162                    09:03:00
# 1163                    10:05:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 1140                          8146290-92.2021.8.05.0001
# 1141                          0501306-57.2018.8.05.0112
# 1159                          8000210-95.2021.8.05.0087
# 1160                          0302538-27.2017.8.05.0079
# 1162                          0303485-70.2018.8.05.0039
# 1163                          0500057-58.2020.8.05.0126
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 1140                                2021-12-16 00:00:00
# 1141                                2018-09-27 00:00:00
# 1159                                2021-03-31 00:00:00
# 1160                                2017-10-31 00:00:00
# 1162                                2018-08-30 00:00:00
# 1163                                           1/1/0001
#
#      5 - É caso de interesse?  \
# 1140       sim: morte externa
# 1141                      não
# 1159                      não
# 1160       sim: morte externa
# 1162       sim: morte externa
# 1163                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 1140                                                PJE
# 1141                                                NaN
# 1159                                                NaN
# 1160                                               SEEU
# 1162                                               SEEU
# 1163                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 1140                                                1.0
# 1141                                                NaN
# 1159                                                NaN
# 1160                                                1.0
# 1162                                                1.0
# 1163                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 1140                                                1.0
# 1141                                                NaN
# 1159                                                NaN
# 1160                                                1.0
# 1162                                                1.0
# 1163                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 1140                                               TJBA
# 1141                                                NaN
# 1159                                                NaN
# 1160                                               TJBA
# 1162                                               TJBA
# 1163                                                NaN
#
#       ... URL do questionário       Endereço de e-mail  \
# 1140  ...                 NaN  anaclaraklink@gmail.com
# 1141  ...                 NaN  anaclaraklink@gmail.com
# 1159  ...                 NaN  anaclaraklink@gmail.com
# 1160  ...                 NaN  anaclaraklink@gmail.com
# 1162  ...                 NaN  anaclaraklink@gmail.com
# 1163  ...                 NaN  anaclaraklink@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 1140                                      não se aplica
# 1141  Processo digital, encontrado, mas sob restriçã...
# 1159                      Pessoa não passou pela prisão
# 1160                                      não se aplica
# 1162                                      não se aplica
# 1163  Processo digital, encontrado, mas sob restriçã...
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 1140                                                Não
# 1141                                                Não
# 1159                                                Não
# 1160                                                Não
# 1162                                                Não
# 1163                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 1140                                                NSA
# 1141                                                NSA
# 1159                                                NSA
# 1160                                                NSA
# 1162                                                NSA
# 1163                                                NSA
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 1140                                       Salvador         NaN
# 1141                                            NaN         NaN
# 1159                                            NaN         NaN
# 1160                                      Eunápolis         NaN
# 1162                                       Camaçari         NaN
# 1163                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 1140     apenas no curso do processo analisado
# 1141                                       NaN
# 1159                                       NaN
# 1160                                     ambos
# 1162     apenas no curso do processo analisado
# 1163                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 1140                                                NSA
# 1141                                                NaN
# 1159                                                NaN
# 1160                           0000261-22.2016.805.0023
# 1162                                                 SI
# 1163                                                NaN
#
#      Estado
# 1140     BA
# 1141     BA
# 1159     BA
# 1160     BA
# 1162     BA
# 1163     BA
#
# [6 rows x 92 columns]

# %%
# 6 - CE

filter_ce = df_final["Estado"] == "CE"
df_filt_ce = df_final[filter_ce]

print(df_filt_ce.value_counts(subset = ['Endereço de e-mail']))


filter_2_ce = df_filt_ce['Endereço de e-mail'] == "marimzambom@gmail.com"
df_filt_ce_dv = df_filt_ce[filter_2_ce]

print(df_filt_ce_dv)
# Out:
# Endereço de e-mail
# manuela.valenca@ufpe.br    55
# marimzambom@gmail.com       6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 2717 2022-10-07 09:40:34.943    Mariana Morais Zambom
# 2718 2022-11-01 18:11:08.112    Mariana Morais Zambom
# 2719 2022-10-07 11:02:30.159    Mariana Morais Zambom
# 2720 2022-10-07 11:03:34.295    Mariana Morais Zambom
# 2721 2022-10-07 11:04:34.349    Mariana Morais Zambom
# 2722 2022-10-07 11:23:55.654    Mariana Morais Zambom
#
#      2 - início do preenchimento  \
# 2717                    09:20:00
# 2718                    09:40:00
# 2719                    11:02:00
# 2720                    11:02:00
# 2721                    11:03:00
# 2722                    11:04:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 2717                          0122911-76.2017.8.06.0001
# 2718                          8003418-61.2020.8.06.0001
# 2719                          0000104-30.2017.8.06.0203
# 2720                          0017088-07.2017.8.06.0101
# 2721                          0002993-56.2017.8.06.0073
# 2722                          0002164-61.2019.8.06.0055
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 2717                                2017-04-04 00:00:00
# 2718                                2020-11-06 00:00:00
# 2719                                2017-03-20 00:00:00
# 2720                                2017-11-28 00:00:00
# 2721                                2017-07-31 00:00:00
# 2722                                2021-01-12 00:00:00
#
#      5 - É caso de interesse?  \
# 2717                      não
# 2718       sim: morte externa
# 2719                      não
# 2720                      não
# 2721                      não
# 2722                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 2717                                                NaN
# 2718                                               SEEU
# 2719                                                NaN
# 2720                                                NaN
# 2721                                                NaN
# 2722                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 2717                                                NaN
# 2718                                                1.0
# 2719                                                NaN
# 2720                                                NaN
# 2721                                                NaN
# 2722                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 2717                                                NaN
# 2718                                                1.0
# 2719                                                NaN
# 2720                                                NaN
# 2721                                                NaN
# 2722                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 2717                                                NaN
# 2718                                               TJCE
# 2719                                                NaN
# 2720                                                NaN
# 2721                                                NaN
# 2722                                                NaN
#
#       ... URL do questionário     Endereço de e-mail  \
# 2717  ...                 NaN  marimzambom@gmail.com
# 2718  ...                 NaN  marimzambom@gmail.com
# 2719  ...                 NaN  marimzambom@gmail.com
# 2720  ...                 NaN  marimzambom@gmail.com
# 2721  ...                 NaN  marimzambom@gmail.com
# 2722  ...                 NaN  marimzambom@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 2717                      Pessoa não passou pela prisão
# 2718                                      não se aplica
# 2719                                    Processo físico
# 2720                                    Processo físico
# 2721                                    Processo físico
# 2722                      Pessoa não passou pela prisão
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 2717                                                Não
# 2718                                                Não
# 2719                                                Não
# 2720                                                Não
# 2721                                                Não
# 2722                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 2717                                                NSA
# 2718                                                NSA
# 2719                                                NSA
# 2720                                                NSA
# 2721                                                NSA
# 2722                                                NSA
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 2717                                            NaN         NaN
# 2718                                      FORTALEZA         NaN
# 2719                                            NaN         NaN
# 2720                                            NaN         NaN
# 2721                                            NaN         NaN
# 2722                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 2717                                       NaN
# 2718     apenas no curso do processo analisado
# 2719                                       NaN
# 2720                                       NaN
# 2721                                       NaN
# 2722                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 2717                                                NaN
# 2718                                                NSA
# 2719                                                NaN
# 2720                                                NaN
# 2721                                                NaN
# 2722                                                NaN
#
#      Estado
# 2717     CE
# 2718     CE
# 2719     CE
# 2720     CE
# 2721     CE
# 2722     CE
#
# [6 rows x 92 columns]

# %%
# 7 - DF

filter = df_final["Estado"] == "DF"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))


filter_2 = df_filt['Endereço de e-mail'] == "gabriellenascimento@usp.br"
df_filt_df_dv = df_filt[filter_2]

print(df_filt_df_dv)
# Out:
# Endereço de e-mail
# anandaendo@usp.br              93
# anabeatrizgpassos@gmail.com     7
# gabriellenascimento@usp.br      7
# anandanendo@usp.br              1
# dtype: int64
#        Carimbo de data/hora 1 - Nome do pesquisadora  \
# 800 2022-07-12 23:11:22.762     Gabrielle Nascimento
# 905 2022-07-19 12:05:02.791     Gabrielle Nascimento
# 906 2022-07-19 12:06:30.420     Gabrielle Nascimento
# 907 2022-07-19 12:08:27.308     Gabrielle Nascimento
# 908 2022-07-19 12:10:13.328     Gabrielle Nascimento
# 909 2022-07-19 12:11:57.195     Gabrielle Nascimento
# 915 2022-07-19 14:58:48.430     Gabrielle Nascimento
#
#     2 - início do preenchimento  \
# 800                    22:08:00
# 905                    12:02:00
# 906                    12:05:00
# 907                    12:07:00
# 908                    12:09:00
# 909                    12:11:00
# 915                    14:57:00
#
#     3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 800                          0401873-89.2019.8.07.0015
# 905                          0006055-72.2017.8.07.0010
# 906                          0000216-81.2017.8.07.0005
# 907                          0000216-81.2017.8.07.0005
# 908                          0002223-81.2019.8.07.0003
# 909                          0004664-76.2017.8.07.0012
# 915                          0402473-76.2020.8.07.0015
#
#     4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 800                                2018-06-21 00:00:00
# 905                                                NaN
# 906                                                NaN
# 907                                                NaN
# 908                                                NaN
# 909                                                NaN
# 915                                                NaN
#
#     5 - É caso de interesse?  \
# 800       sim: morte externa
# 905                      NaN
# 906                      NaN
# 907                      NaN
# 908                      NaN
# 909                      NaN
# 915                      NaN
#
#     6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 800                                               SEEU
# 905  Sistema de pesquisa próprio do tribunal estadu...
# 906                                                NaN
# 907                                                NaN
# 908                                                NaN
# 909                                                NaN
# 915                                                NaN
#
#     7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 800                                                1.0
# 905                                                NaN
# 906                                                NaN
# 907                                                NaN
# 908                                                NaN
# 909                                                NaN
# 915                                                NaN
#
#     8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 800                                                1.0
# 905                                                NaN
# 906                                                NaN
# 907                                                NaN
# 908                                                NaN
# 909                                                NaN
# 915                                                NaN
#
#     9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 800                                               TJDF
# 905                                                NaN
# 906                                                NaN
# 907                                                NaN
# 908                                                NaN
# 909                                                NaN
# 915                                                NaN
#
#      ... URL do questionário          Endereço de e-mail  \
# 800  ...                 NaN  gabriellenascimento@usp.br
# 905  ...                 NaN  gabriellenascimento@usp.br
# 906  ...                 NaN  gabriellenascimento@usp.br
# 907  ...                 NaN  gabriellenascimento@usp.br
# 908  ...                 NaN  gabriellenascimento@usp.br
# 909  ...                 NaN  gabriellenascimento@usp.br
# 915  ...                 NaN  gabriellenascimento@usp.br
#
#     5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 800                                                NaN
# 905                                    Processo físico
# 906                                                NaN
# 907                                                NaN
# 908                                                NaN
# 909                                                NaN
# 915                                                NaN
#
#     3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 800                                                Não
# 905                                                Sim
# 906                                                Sim
# 907                                                Sim
# 908                                                Sim
# 909                                                Sim
# 915                                                Sim
#
#     3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 800                                                NaN
# 905                                    Processo físico
# 906                                    Processo físico
# 907                                    Processo físico
# 908                                    Processo físico
# 909                                    Processo físico
# 915                          Não encontrado no sistema
#
#     10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 800                      Comarca de São Sebastião          NaN
# 905                                            NaN         NaN
# 906                                            NaN         NaN
# 907                                            NaN         NaN
# 908                                            NaN         NaN
# 909                                            NaN         NaN
# 915                                            NaN         NaN
#
#     5.2. O evento "prisão do agente" ocorreu:  \
# 800     apenas no curso do processo analisado
# 905                                       NaN
# 906                                       NaN
# 907                                       NaN
# 908                                       NaN
# 909                                       NaN
# 915                                       NaN
#
#     5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 800                                                NaN
# 905                                                NaN
# 906                                                NaN
# 907                                                NaN
# 908                                                NaN
# 909                                                NaN
# 915                                                NaN
#
#     Estado
# 800     DF
# 905     DF
# 906     DF
# 907     DF
# 908     DF
# 909     DF
# 915     DF
#
# [7 rows x 92 columns]

# %%
# 8 -ES

filter = df_final["Estado"] == "ES"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "manuela.valenca@ufpe.br"
df_filt_es_dv = df_filt[filter_2]

print(df_filt_es_dv)
# Out:
# Endereço de e-mail
# anaclaraklink@gmail.com    54
# manuela.valenca@ufpe.br     6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 3150 2022-11-01 22:34:51.042            Manuela Abath
# 3976 2022-11-24 09:26:54.523            Manuela Abath
# 3977 2022-11-24 09:27:34.974            Manuela Abath
# 3978 2022-11-24 09:28:15.378            Manuela Abath
# 3979 2022-11-24 09:29:03.611            Manuela Abath
# 3980 2022-11-24 09:29:46.102            Manuela Abath
#
#      2 - início do preenchimento  \
# 3150                    22:26:00
# 3976                    09:26:00
# 3977                         NaN
# 3978                    09:27:00
# 3979                    09:28:00
# 3980                    09:29:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 3150                          2000528-16.2021.8.08.0050
# 3976                          0001348-14.2017.8.08.0049
# 3977                          0000005-54.2019.8.08.0035
# 3978                          0026466-24.2019.8.08.0048
# 3979                          0000246-84.2020.8.08.0005
# 3980                          0002456-44.2017.8.08.0028
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 3150                                2003-11-04 00:00:00
# 3976                                                NaN
# 3977                                                NaN
# 3978                                                NaN
# 3979                                                NaN
# 3980                                                NaN
#
#      5 - É caso de interesse?  \
# 3150       sim: morte interna
# 3976                      não
# 3977                      não
# 3978                      não
# 3979                      não
# 3980                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 3150                                               SEEU
# 3976                                                NaN
# 3977                                                NaN
# 3978                                                NaN
# 3979                                                NaN
# 3980                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 3150                                                1.0
# 3976                                                NaN
# 3977                                                NaN
# 3978                                                NaN
# 3979                                                NaN
# 3980                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 3150                                                1.0
# 3976                                                NaN
# 3977                                                NaN
# 3978                                                NaN
# 3979                                                NaN
# 3980                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 3150                                               TJES
# 3976                                                NaN
# 3977                                                NaN
# 3978                                                NaN
# 3979                                                NaN
# 3980                                                NaN
#
#       ... URL do questionário       Endereço de e-mail  \
# 3150  ...                 NaN  manuela.valenca@ufpe.br
# 3976  ...                 NaN  manuela.valenca@ufpe.br
# 3977  ...                 NaN  manuela.valenca@ufpe.br
# 3978  ...                 NaN  manuela.valenca@ufpe.br
# 3979  ...                 NaN  manuela.valenca@ufpe.br
# 3980  ...                 NaN  manuela.valenca@ufpe.br
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 3150                                      não se aplica
# 3976                                                NaN
# 3977                                    Processo físico
# 3978                                    Processo físico
# 3979                                    Processo físico
# 3980                                    Processo físico
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 3150                                                Não
# 3976                                                Não
# 3977                                                Não
# 3978                                                Não
# 3979                                                Sim
# 3980                                                Sim
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 3150                                                NSA
# 3976                                      Autos físicos
# 3977                                      autos físicos
# 3978                                                NaN
# 3979                                      Autos físicos
# 3980                                      Autos físicos
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 3150                                          Viana         NaN
# 3976                                            NaN         NaN
# 3977                                            NaN         NaN
# 3978                                            NaN         NaN
# 3979                                            NaN         NaN
# 3980                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 3150     apenas no curso do processo analisado
# 3976                                       NaN
# 3977                                       NaN
# 3978                                       NaN
# 3979                                       NaN
# 3980                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 3150                                                NSA
# 3976                                                NaN
# 3977                                                NaN
# 3978                                                NaN
# 3979                                                NaN
# 3980                                                NaN
#
#      Estado
# 3150     ES
# 3976     ES
# 3977     ES
# 3978     ES
# 3979     ES
# 3980     ES
#
# [6 rows x 92 columns]

# %%
# 9 - GO

# não tem os de conferência

filter = df_final["Estado"] == "GO"
df_filt= df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "manuela.valenca@ufpe.br"
df_filt_go_dv = df_filt[filter_2]

print(df_filt_go_dv)
# Out:
# Endereço de e-mail
# viviane.balbuglio@gmail.com    93
# manuela.valenca@ufpe.br         2
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 4000 2022-11-29 15:45:01.549            Manuela Abath
# 4001 2022-11-29 15:49:50.961            Manuela Abath
#
#      2 - início do preenchimento  \
# 4000                         NaN
# 4001                         NaN
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 4000                          0134343-20.2019.8.09.0137
# 4001                          0006547-68.2019.8.09.0162
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 4000                                                NaN
# 4001                                                NaN
#
#      5 - É caso de interesse?  \
# 4000                      não
# 4001                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 4000                                                NaN
# 4001                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 4000                                                NaN
# 4001                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 4000                                                NaN
# 4001                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 4000                                                NaN
# 4001                                                NaN
#
#       ... URL do questionário       Endereço de e-mail  \
# 4000  ...                 NaN  manuela.valenca@ufpe.br
# 4001  ...                 NaN  manuela.valenca@ufpe.br
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 4000                      Pessoa não passou pela prisão
# 4001                      Pessoa não passou pela prisão
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 4000                                                Não
# 4001                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 4000                                                NaN
# 4001                                                NaN
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 4000                                            NaN         NaN
# 4001                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 4000                                       NaN
# 4001                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 4000                                                NaN
# 4001                                                NaN
#
#      Estado
# 4000     GO
# 4001     GO
#
# [2 rows x 92 columns]

# %%
# 10 - MA    

filter = df_final["Estado"] == "MA"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "manuela.valenca@ufpe.br"
df_filt_ma_dv = df_filt[filter_2]

print(df_filt_ma_dv)
# Out:
# Endereço de e-mail
# gabriellenascimento@usp.br        293
# manuela.valenca@ufpe.br             6
# gabriellenascimento@usp.br          3
# gabrellenascimento@usp.br           1
# gabriellenasccimento@usp.br         1
# gabriellenascimento@usp.org.br      1
# gavbriellenascimento@usp.br         1
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 3986 2022-11-24 20:35:15.983            Manuela Abath
# 3987 2022-11-24 20:37:04.378            Manuela Abath
# 3988 2022-11-24 20:39:32.309            Manuela Abath
# 3989 2022-11-24 20:55:28.412            Manuela Abath
# 3990 2022-11-24 20:56:50.673            Manuela Abath
# 3991 2022-11-24 20:58:34.112            Manuela Abath
#
#      2 - início do preenchimento  \
# 3986                         NaN
# 3987                         NaN
# 3988                         NaN
# 3989                    20:48:00
# 3990                    20:56:00
# 3991                         NaN
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 3986                          0000164-36.2019.8.10.0004
# 3987                          0001778-05.2019.8.10.0060
# 3988                          0008962-92.2019.8.10.0001
# 3989                 Mazurkiévicz Saraiva de Sousa Cruz
# 3990                          0000009-73.2019.8.10.0023
# 3991                          0001897-43.2017.8.10.0057
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 3986                                                NaN
# 3987                                                NaN
# 3988                                                NaN
# 3989                                2020-04-13 00:00:00
# 3990                                                NaN
# 3991                                                NaN
#
#      5 - É caso de interesse?  \
# 3986                      não
# 3987                      não
# 3988                      não
# 3989       sim: morte externa
# 3990                      não
# 3991                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 3986                                                NaN
# 3987                                                NaN
# 3988                                                NaN
# 3989                                                PJE
# 3990                                                NaN
# 3991                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 3986                                                NaN
# 3987                                                NaN
# 3988                                                NaN
# 3989                                                1.0
# 3990                                                NaN
# 3991                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 3986                                                NaN
# 3987                                                NaN
# 3988                                                NaN
# 3989                                                1.0
# 3990                                                NaN
# 3991                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 3986                                                NaN
# 3987                                                NaN
# 3988                                                NaN
# 3989                                               TJMA
# 3990                                                NaN
# 3991                                                NaN
#
#       ... URL do questionário       Endereço de e-mail  \
# 3986  ...                 NaN  manuela.valenca@ufpe.br
# 3987  ...                 NaN  manuela.valenca@ufpe.br
# 3988  ...                 NaN  manuela.valenca@ufpe.br
# 3989  ...                 NaN  manuela.valenca@ufpe.br
# 3990  ...                 NaN  manuela.valenca@ufpe.br
# 3991  ...                 NaN  manuela.valenca@ufpe.br
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 3986                                    Processo físico
# 3987                                    Processo físico
# 3988                                    Processo físico
# 3989                                      não se aplica
# 3990                                    Processo físico
# 3991                                    Processo físico
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 3986                                                Sim
# 3987                                                Sim
# 3988                                                Sim
# 3989                                                Não
# 3990                                                Sim
# 3991                                                Sim
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 3986                                                NaN
# 3987                                                NaN
# 3988                                                NaN
# 3989                                                NSA
# 3990                                                NaN
# 3991                                                NaN
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 3986                                            NaN         NaN
# 3987                                            NaN         NaN
# 3988                                            NaN         NaN
# 3989                                       Carolina         NaN
# 3990                                            NaN         NaN
# 3991                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 3986                                       NaN
# 3987                                       NaN
# 3988                                       NaN
# 3989     apenas no curso do processo analisado
# 3990                                       NaN
# 3991                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 3986                                                NaN
# 3987                                                NaN
# 3988                                                NaN
# 3989                                                NSA
# 3990                                                NaN
# 3991                                                NaN
#
#      Estado
# 3986     MA
# 3987     MA
# 3988     MA
# 3989     MA
# 3990     MA
# 3991     MA
#
# [6 rows x 92 columns]

# %%
# 11 - MS

filter = df_final["Estado"] == "MS"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "marimzambom@gmail.com"
df_filt_ms_dv = df_filt[filter_2]

print(df_filt_ms_dv)
# Out:
# Endereço de e-mail
# viviane.balbuglio@gmail.com    73
# anaclaraklink@gmail.com        10
# marimzambom@gmail.com           6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 1381 2022-08-10 10:21:04.644    Mariana Morais Zambom
# 1383 2022-08-10 11:26:17.360    Mariana Morais Zambom
# 1385 2022-08-10 14:00:32.502    Mariana Morais Zambom
# 1410 2022-08-10 18:33:02.882    Mariana Morais Zambom
# 1411 2022-08-10 18:50:54.816    Mariana Morais Zambom
# 1412 2022-08-10 19:06:25.198    Mariana Morais Zambom
#
#      2 - início do preenchimento  \
# 1381                    09:00:00
# 1383                    10:45:00
# 1385                    12:30:00
# 1410                    18:10:00
# 1411                    18:40:00
# 1412                    18:52:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 1381                          0007211-47.2018.8.12.0002
# 1383                          0000205-90.2019.8.12.0054
# 1385                          0002935-43.2018.8.12.0011
# 1410                          0004621-83.2017.8.12.0018
# 1411                          0007925-37.2019.8.12.0110
# 1412                          0002596-12.2017.8.12.0014
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 1381                                           1/1/0001
# 1383                                2019-02-07 00:00:00
# 1385                                2019-11-15 00:00:00
# 1410                                           1/1/0001
# 1411                                           1/1/0001
# 1412                                           1/1/0001
#
#      5 - É caso de interesse?  \
# 1381       sim: morte externa
# 1383       sim: morte externa
# 1385       sim: morte interna
# 1410                      não
# 1411                      não
# 1412                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 1381                                              E-SAJ
# 1383                                              E-SAJ
# 1385                                               SEEU
# 1410                                                NaN
# 1411                                                NaN
# 1412                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 1381                                                1.0
# 1383                                                1.0
# 1385                                                1.0
# 1410                                                NaN
# 1411                                                NaN
# 1412                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 1381                                                1.0
# 1383                                                1.0
# 1385                                                1.0
# 1410                                                NaN
# 1411                                                NaN
# 1412                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 1381                                               TJMS
# 1383                                               TJMS
# 1385                                               TJMS
# 1410                                                NaN
# 1411                                                NaN
# 1412                                                NaN
#
#       ... URL do questionário     Endereço de e-mail  \
# 1381  ...                 NaN  marimzambom@gmail.com
# 1383  ...                 NaN  marimzambom@gmail.com
# 1385  ...                 NaN  marimzambom@gmail.com
# 1410  ...                 NaN  marimzambom@gmail.com
# 1411  ...                 NaN  marimzambom@gmail.com
# 1412  ...                 NaN  marimzambom@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 1381                                      não se aplica
# 1383                                      não se aplica
# 1385                                      não se aplica
# 1410                      Pessoa não passou pela prisão
# 1411                      Pessoa não passou pela prisão
# 1412                      Pessoa não passou pela prisão
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 1381                                                Não
# 1383                                                Não
# 1385                                                Não
# 1410                                                Não
# 1411                                                Não
# 1412                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 1381                                                NSA
# 1383                                                NSA
# 1385                                                NSA
# 1410                                                NSA
# 1411                                                NSA
# 1412                                                NSA
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 1381                                       Dourados         NaN
# 1383                           NOVA ALVORADA DO SUL         NaN
# 1385                                   Campo Grande         NaN
# 1410                                            NaN         NaN
# 1411                                            NaN         NaN
# 1412                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 1381     apenas no curso do processo analisado
# 1383     apenas no curso do processo analisado
# 1385                                     ambos
# 1410                                       NaN
# 1411                                       NaN
# 1412                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 1381                                                NSA
# 1383                                                NSA
# 1385  0022534-18.2006.8.12.0001; 0074255-77.2004.8.1...
# 1410                                                NaN
# 1411                                                NaN
# 1412                                                NaN
#
#      Estado
# 1381     MS
# 1383     MS
# 1385     MS
# 1410     MS
# 1411     MS
# 1412     MS
#
# [6 rows x 92 columns]

# %%
# 12 - MG

filter = df_final["Estado"] == "MG"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "anabeatrizgpassos@gmail.com"
df_filt_mg_dv = df_filt[filter_2]

print(df_filt_mg_dv)
# Out:
# Endereço de e-mail
# manuela.valenca@ufpe.br        60
# anabeatrizgpassos@gmail.com     6
# dtype: int64
#         Carimbo de data/hora      1 - Nome do pesquisadora  \
# 1051 2022-07-25 17:24:58.583  Ana Beatriz Guimarães Passos
# 1052 2022-07-25 17:33:56.293  Ana Beatriz Guimarães Passos
# 1053 2022-07-25 17:41:30.525  Ana Beatriz Guimarães Passos
# 1054 2022-08-08 18:57:03.357  Ana Beatriz Guimarães Passos
# 1055 2022-07-25 21:26:24.888  Ana Beatriz Guimarães Passos
# 1056 2022-07-25 21:32:23.369  Ana Beatriz Guimarães Passos
#
#      2 - início do preenchimento  \
# 1051                    17:18:00
# 1052                    17:29:00
# 1053                    17:36:00
# 1054                    19:03:00
# 1055                    21:23:00
# 1056                    21:29:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 1051                          0042260-77.2020.8.13.0738
# 1052                          0000877-57.2017.8.13.0243
# 1053                          0027242-53.2018.8.13.0134
# 1054                          4400014-03.2019.8.13.0338
# 1055                          0014367-37.2021.8.13.0040
# 1056                          0024499-31.2020.8.13.0480
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054                                2019-02-11 00:00:00
# 1055                                                NaN
# 1056                                                NaN
#
#      5 - É caso de interesse?  \
# 1051                      NaN
# 1052                      NaN
# 1053                      NaN
# 1054       sim: morte interna
# 1055                      NaN
# 1056                      NaN
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054                                               SEEU
# 1055                                                NaN
# 1056                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054                                                1.0
# 1055                                                NaN
# 1056                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054                                                1.0
# 1055                                                NaN
# 1056                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054                                               TJMG
# 1055                                                NaN
# 1056                                                NaN
#
#       ... URL do questionário           Endereço de e-mail  \
# 1051  ...                 NaN  anabeatrizgpassos@gmail.com
# 1052  ...                 NaN  anabeatrizgpassos@gmail.com
# 1053  ...                 NaN  anabeatrizgpassos@gmail.com
# 1054  ...                 NaN  anabeatrizgpassos@gmail.com
# 1055  ...                 NaN  anabeatrizgpassos@gmail.com
# 1056  ...                 NaN  anabeatrizgpassos@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 1051                                                Sim
# 1052                                                Sim
# 1053                                                Sim
# 1054                                                Não
# 1055                                                Sim
# 1056                                                Sim
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 1051                         Não encontrado no sistema.
# 1052                         Não encontrado no sistema.
# 1053                         Não encontrado no sistema.
# 1054                                                NaN
# 1055                        Não encontrado no sistema.
# 1056                        Não encontrado no sistema.
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 1051                                            NaN         NaN
# 1052                                            NaN         NaN
# 1053                                            NaN         NaN
# 1054                              Comarca de Itaúna         NaN
# 1055                                            NaN         NaN
# 1056                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 1051                                       NaN
# 1052                                       NaN
# 1053                                       NaN
# 1054     apenas no curso do processo analisado
# 1055                                       NaN
# 1056                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
#
#      Estado
# 1051     MG
# 1052     MG
# 1053     MG
# 1054     MG
# 1055     MG
# 1056     MG
#
# [6 rows x 92 columns]

# %%
# 13 - MT

filter = df_final["Estado"] == "MT"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "viviane.balbuglio@gmail.com"
df_filt_mt_dv = df_filt[filter_2]

## endereços da ana clara errados

print(df_filt_mt_dv)
# Out:
# Endereço de e-mail
# anaclaraklink@gmail.com        263
# viviane.balbuglio@gmail.com      6
# anaclaraklinK@gmail.com          1
# anaclarklink@gmail.com           1
# dtype: int64
#         Carimbo de data/hora     1 - Nome do pesquisadora  \
# 3300 2022-11-07 12:05:33.765            Viviane Balbuglio
# 3301 2022-11-07 12:12:24.342            Viviane Balbuglio
# 3302 2022-11-07 12:19:14.730            VIviane Balbuglio
# 3303 2022-11-07 12:28:39.868            Viviane Balbuglio
# 3305 2022-11-07 13:06:06.574  viviane.balbuglio@gmail.com
# 3306 2022-11-07 13:09:40.401            Viviane Balbuglio
#
#      2 - início do preenchimento  \
# 3300                    11:49:00
# 3301                    12:10:00
# 3302                    12:12:00
# 3303                    12:19:00
# 3305                    12:30:00
# 3306                    13:06:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 3300                          1000393-63.2021.8.11.0009
# 3301                          0005004-79.2019.8.11.0063
# 3302                          1001322-67.2020.8.11.0030
# 3303                           1017927-72.2020.811.0003
# 3305                          2000085-66.2019.8.11.0013
# 3306                           0001809-59.2017.811.0030
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 3300                                2021-02-26 00:00:00
# 3301                                                NaN
# 3302                                2020-12-16 00:00:00
# 3303                                2020-09-03 00:00:00
# 3305                                2019-11-28 00:00:00
# 3306                                                NaN
#
#      5 - É caso de interesse?  \
# 3300                      não
# 3301                      não
# 3302                      não
# 3303                      não
# 3305       sim: morte externa
# 3306                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 3300                                                PJE
# 3301                                                NaN
# 3302                                                PJE
# 3303                                                PJE
# 3305                                               SEEU
# 3306                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 3300                                                NaN
# 3301                                                NaN
# 3302                                                NaN
# 3303                                                NaN
# 3305                                                1.0
# 3306                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 3300                                                NaN
# 3301                                                NaN
# 3302                                                NaN
# 3303                                                NaN
# 3305                                                1.0
# 3306                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 3300                                               TJMT
# 3301                                                NaN
# 3302                                               TJMT
# 3303                                               TJMT
# 3305                                               TJMT
# 3306                                                NaN
#
#       ... URL do questionário           Endereço de e-mail  \
# 3300  ...                 NaN  viviane.balbuglio@gmail.com
# 3301  ...                 NaN  viviane.balbuglio@gmail.com
# 3302  ...                 NaN  viviane.balbuglio@gmail.com
# 3303  ...                 NaN  viviane.balbuglio@gmail.com
# 3305  ...                 NaN  viviane.balbuglio@gmail.com
# 3306  ...                 NaN  viviane.balbuglio@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 3300                      Pessoa não passou pela prisão
# 3301                                    Processo físico
# 3302                      Pessoa não passou pela prisão
# 3303                      Pessoa não passou pela prisão
# 3305                                      não se aplica
# 3306                                    Processo físico
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 3300                                                Não
# 3301                                                Não
# 3302                                                Não
# 3303                                                Não
# 3305                                                Não
# 3306                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 3300                                                NaN
# 3301                                                NaN
# 3302                                                NaN
# 3303                                                NaN
# 3305                                                NaN
# 3306                                                NaN
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 3300                                        COLÍDER         NaN
# 3301                                            NaN         NaN
# 3302                                            NaN         NaN
# 3303                                            NaN         NaN
# 3305                             PONTES E LACERDA\t         NaN
# 3306                                            NaN         NaN
#
#               5.2. O evento "prisão do agente" ocorreu:  \
# 3300                                      não se aplica
# 3301                                      não se aplica
# 3302                                                NaN
# 3303  apenas em outro(s) processo(s) - relatado no p...
# 3305              apenas no curso do processo analisado
# 3306                                                NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 3300                                                NaN
# 3301                                                NaN
# 3302                                                NaN
# 3303                                                 SI
# 3305                                                NaN
# 3306                                                NaN
#
#      Estado
# 3300     MT
# 3301     MT
# 3302     MT
# 3303     MT
# 3305     MT
# 3306     MT
#
# [6 rows x 92 columns]

# %%
# 14 - PA


filter = df_final["Estado"] == "PA"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "anaclaraklink@gmail.com"
df_filt_pa_dv = df_filt[filter_2]

print(df_filt_pa_dv)
# Out:
# Endereço de e-mail
# marimzambom@gmail.com      234
# anaclaraklink@gmail.com      6
# marimzambom@gmai.com         1
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 1316 2022-08-05 09:29:12.573                Ana Clara
# 1318 2022-11-13 07:51:33.459                Ana Clara
# 1319 2022-08-05 16:35:05.089                Ana Clara
# 1320 2022-08-05 16:41:46.286                Ana Clara
# 3981 2022-11-24 15:22:03.033                Ana Clara
# 3982 2022-11-24 15:22:56.528                Ana Clara
#
#      2 - início do preenchimento  \
# 1316                    09:21:00
# 1318                    09:35:00
# 1319                    14:33:00
# 1320                    16:38:00
# 3981                    15:20:00
# 3982                    15:22:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 1316                          0008134-20.2017.8.14.0401
# 1318                          0006286-73.2020.8.14.0051
# 1319                          0000769-38.2019.8.14.0014
# 1320                          0800707-49.2020.8.14.0104
# 3981                             3003-76.2019.8.14.0051
# 3982                          0015900-27.2017.8.14.0401
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 1316                                2017-04-03 00:00:00
# 1318                                2020-07-07 00:00:00
# 1319                                2019-03-20 00:00:00
# 1320                                2020-08-26 00:00:00
# 3981                                           1/1/0001
# 3982                                           1/1/0001
#
#      5 - É caso de interesse?  \
# 1316                      não
# 1318       sim: morte externa
# 1319       sim: morte externa
# 1320                      não
# 3981                      não
# 3982                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 1316                                                NaN
# 1318                                               SEEU
# 1319                                                PJE
# 1320                                                NaN
# 3981                                                NaN
# 3982                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 1316                                                NaN
# 1318                                                1.0
# 1319                                                2.0
# 1320                                                NaN
# 3981                                                NaN
# 3982                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 1316                                                NaN
# 1318                                                1.0
# 1319                                                2.0
# 1320                                                NaN
# 3981                                                NaN
# 3982                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 1316                                                NaN
# 1318                                               TJPA
# 1319                                               TJPA
# 1320                                                NaN
# 3981                                               TJPA
# 3982                                               TJPA
#
#       ... URL do questionário       Endereço de e-mail  \
# 1316  ...                 NaN  anaclaraklink@gmail.com
# 1318  ...                 NaN  anaclaraklink@gmail.com
# 1319  ...                 NaN  anaclaraklink@gmail.com
# 1320  ...                 NaN  anaclaraklink@gmail.com
# 3981  ...                 NaN  anaclaraklink@gmail.com
# 3982  ...                 NaN  anaclaraklink@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 1316                      Pessoa não passou pela prisão
# 1318                                      não se aplica
# 1319                                      não se aplica
# 1320                      Pessoa não passou pela prisão
# 3981                                      não se aplica
# 3982                            Processo não encontrado
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 1316                                                Não
# 1318                                                Não
# 1319                                                Não
# 1320                                                Não
# 3981                                                Sim
# 3982                                                Sim
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 1316                                                NSA
# 1318                                                NSA
# 1319                                                NSA
# 1320                                                NSA
# 3981                          Não encontrado no sistema
# 3982                          Não encontrado no sistema
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 1316                                            NaN         NaN
# 1318                                       Santarém         NaN
# 1319                                 Capitação Poço         NaN
# 1320                                            NaN         NaN
# 3981                                            NaN         NaN
# 3982                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 1316                                       NaN
# 1318                                     ambos
# 1319                                     ambos
# 1320                                       NaN
# 3981                                       NaN
# 3982                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 1316                                                NaN
# 1318  0202441-91.2014.804.001; 0003783-78.2016.814.0...
# 1319         00012690720198140014; 00074878520188140014
# 1320                                                NaN
# 3981                                                NaN
# 3982                                                NaN
#
#      Estado
# 1316     PA
# 1318     PA
# 1319     PA
# 1320     PA
# 3981     PA
# 3982     PA
#
# [6 rows x 92 columns]

# %%
# 15 - PB

filter = df_final["Estado"] == "PB"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "anandaendo@usp.br"
df_filt_pb_dv = df_filt[filter_2]

print(df_filt_pb_dv)
# Out:
# Endereço de e-mail
# marimzambom@gmail.com    104
# anandaendo@usp.br          6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 2731 2022-10-11 16:14:51.270              Ananda Endo
# 2732 2022-10-11 19:39:31.950              Ananda Endo
# 2733 2022-10-11 20:41:09.020              Ananda Endo
# 2741 2022-10-12 13:33:24.711              Ananda Endo
# 2742 2022-10-12 13:35:17.463              Ananda Endo
# 2743 2022-10-13 14:14:37.642              Ananda Endo
#
#      2 - início do preenchimento  \
# 2731                    16:06:00
# 2732                    18:32:00
# 2733                    20:30:00
# 2741                    13:32:00
# 2742                    13:34:00
# 2743                    13:53:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 2731                          8001016-03.2019.8.15.2002
# 2732                          7003525-48.2017.8.15.0011
# 2733                          0000431-19.2018.8.15.0581
# 2741                          0000074-70.2018.8.15.0021
# 2742                          0000543-50.2019.8.15.0161
# 2743                          0000431-19.2018.8.15.0581
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 2731                                2019-09-23 00:00:00
# 2732                                2017-11-23 00:00:00
# 2733                                2018-07-20 00:00:00
# 2741                                                NaN
# 2742                                                NaN
# 2743                                2018-07-20 00:00:00
#
#      5 - É caso de interesse?  \
# 2731       sim: morte externa
# 2732       sim: morte interna
# 2733                      não
# 2741                      NaN
# 2742                      NaN
# 2743       sim: morte externa
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 2731                                               SEEU
# 2732                                               SEEU
# 2733                                                NaN
# 2741                                                NaN
# 2742                                                NaN
# 2743  Sistema de pesquisa próprio do tribunal estadu...
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 2731                                                1.0
# 2732                                                1.0
# 2733                                                NaN
# 2741                                                NaN
# 2742                                                NaN
# 2743                                                1.0
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 2731                                                1.0
# 2732                                                1.0
# 2733                                                NaN
# 2741                                                NaN
# 2742                                                NaN
# 2743                                                1.0
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 2731                                               TJDF
# 2732                                               TJPB
# 2733                                                NaN
# 2741                                                NaN
# 2742                                                NaN
# 2743                                               TJPB
#
#       ... URL do questionário Endereço de e-mail  \
# 2731  ...                 NaN  anandaendo@usp.br
# 2732  ...                 NaN  anandaendo@usp.br
# 2733  ...                 NaN  anandaendo@usp.br
# 2741  ...                 NaN  anandaendo@usp.br
# 2742  ...                 NaN  anandaendo@usp.br
# 2743  ...                 NaN  anandaendo@usp.br
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 2731                                      não se aplica
# 2732                                      não se aplica
# 2733                      Pessoa não passou pela prisão
# 2741                                                NaN
# 2742                                                NaN
# 2743                                      não se aplica
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 2731                                                Não
# 2732                                                Não
# 2733                                                Não
# 2741                                                Sim
# 2742                                                Sim
# 2743                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 2731                                                NSA
# 2732                                                NSA
# 2733                                                NSA
# 2741                      Autos digitais não econtrados
# 2742                     Autos digitais não encontrados
# 2743                                                NSA
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 2731                                    João Pessoa         NaN
# 2732                                 Campina Grande         NaN
# 2733                                            NaN         NaN
# 2741                                            NaN         NaN
# 2742                                            NaN         NaN
# 2743                                      Rio Tinto         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 2731     apenas no curso do processo analisado
# 2732                                     ambos
# 2733                                       NaN
# 2741                                       NaN
# 2742                                       NaN
# 2743                                     ambos
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 2731                                                NSA
# 2732                          0814544-31.2021.8.15.0001
# 2733                                                NaN
# 2741                                                NaN
# 2742                                                NaN
# 2743                                                 SI
#
#      Estado
# 2731     PB
# 2732     PB
# 2733     PB
# 2741     PB
# 2742     PB
# 2743     PB
#
# [6 rows x 92 columns]

# %%
# 16 - PE


filter = df_final["Estado"] == "PE"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "manuela.valenca@ufpe.br"
df_filt_pe_dv = df_filt[filter_2]

print(df_filt_pe_dv)
# Out:
# Endereço de e-mail
# anandaendo@usp.br          312
# manuela.valenca@ufpe.br      5
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 3983 2022-11-24 20:18:55.847            Manuela Abath
# 3984 2022-11-24 20:20:03.960            Manuela Abath
# 3985 2022-11-24 20:20:57.252            Manuela Abath
# 3992 2022-11-24 21:09:01.314            Manuela Abath
# 3993 2022-11-24 21:09:48.037            Manuela Abath
#
#      2 - início do preenchimento  \
# 3983                         NaN
# 3984                         NaN
# 3985                         NaN
# 3992                    21:01:00
# 3993                         NaN
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 3983                          0044792-59.2018.8.17.0810
# 3984                          0000405-71.2019.8.17.1020
# 3985                          0000318-75.2019.8.17.0710
# 3992                          0000814-24.2018.8.17.0360
# 3993                          0019178-88.2017.8.17.0001
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 3983                                                NaN
# 3984                                                NaN
# 3985                                                NaN
# 3992                                                NaN
# 3993                                                NaN
#
#      5 - É caso de interesse?  \
# 3983                      não
# 3984                      não
# 3985                      não
# 3992                      não
# 3993                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 3983                                                NaN
# 3984                                                NaN
# 3985                                                NaN
# 3992                                                NaN
# 3993                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 3983                                                NaN
# 3984                                                NaN
# 3985                                                NaN
# 3992                                                NaN
# 3993                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 3983                                                NaN
# 3984                                                NaN
# 3985                                                NaN
# 3992                                                NaN
# 3993                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 3983                                                NaN
# 3984                                                NaN
# 3985                                                NaN
# 3992                                                NaN
# 3993                                                NaN
#
#       ... URL do questionário       Endereço de e-mail  \
# 3983  ...                 NaN  manuela.valenca@ufpe.br
# 3984  ...                 NaN  manuela.valenca@ufpe.br
# 3985  ...                 NaN  manuela.valenca@ufpe.br
# 3992  ...                 NaN  manuela.valenca@ufpe.br
# 3993  ...                 NaN  manuela.valenca@ufpe.br
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 3983                                    Processo físico
# 3984                                    Processo físico
# 3985                                    Processo físico
# 3992                                    Processo físico
# 3993                                    Processo físico
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 3983                                                Não
# 3984                                                Sim
# 3985                                                Sim
# 3992                                                Sim
# 3993                                                Sim
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 3983                                                NaN
# 3984                                             Físico
# 3985                                                NaN
# 3992                                                NSA
# 3993                                                NaN
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 3983                                            NaN         NaN
# 3984                                            NaN         NaN
# 3985                                            NaN         NaN
# 3992                                            NaN         NaN
# 3993                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 3983                                       NaN
# 3984                                       NaN
# 3985                                       NaN
# 3992                                       NaN
# 3993                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 3983                                                NaN
# 3984                                                NaN
# 3985                                                NaN
# 3992                                                NaN
# 3993                                                NaN
#
#      Estado
# 3983     PE
# 3984     PE
# 3985     PE
# 3992     PE
# 3993     PE
#
# [5 rows x 92 columns]

# %%
# 17 - PI

filter = df_final["Estado"] == "PI"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "viviane.balbuglio@gmail.com"
df_filt_pi_dv = df_filt[filter_2]


print(df_filt_pi_dv)
# Out:
# Endereço de e-mail
# manuela.valenca@ufpe.br        64
# viviane.balbuglio@gmail.com     6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 2656 2022-09-30 14:45:02.735        Viviane Balbuglio
# 2657 2022-09-30 14:45:30.006        Viviane Balbuglio
# 2658 2022-09-30 14:45:58.290        Viviane Balbuglio
# 2659 2022-09-30 14:47:23.817        Viviane Balbuglio
# 2660 2022-09-30 14:48:38.526        Viviane Balbuglio
# 2661 2022-09-30 14:51:05.230        Viviane Balbuglio
#
#      2 - início do preenchimento  \
# 2656                    14:32:00
# 2657                    14:36:00
# 2658                    14:38:00
# 2659                    14:44:00
# 2660                    14:47:00
# 2661                    14:50:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 2656                          0000414-95.2017.8.18.0043
# 2657                          0000018-08.2018.8.18.0036
# 2658                          0000228-66.2018.8.18.0066
# 2659                          0000345-37.2020.8.18.0050
# 2660                          0002951-12.2017.8.18.0028
# 2661                          0000067-79.2017.8.18.0005
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 2656                                2017-07-05 00:00:00
# 2657                                2018-01-11 00:00:00
# 2658                                2018-09-20 00:00:00
# 2659                                2020-07-03 00:00:00
# 2660                                2017-10-31 00:00:00
# 2661                                                NaN
#
#      5 - É caso de interesse?  \
# 2656                      não
# 2657                      não
# 2658                      não
# 2659                      não
# 2660                      não
# 2661                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 2656  Sistema de pesquisa próprio do tribunal estadu...
# 2657  Sistema de pesquisa próprio do tribunal estadu...
# 2658  Sistema de pesquisa próprio do tribunal estadu...
# 2659  Sistema de pesquisa próprio do tribunal estadu...
# 2660  Sistema de pesquisa próprio do tribunal estadu...
# 2661                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 2656                                                1.0
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
# 2660                                                NaN
# 2661                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
# 2660                                                NaN
# 2661                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 2656                                               TJPI
# 2657                                               TJPI
# 2658                                               TJPI
# 2659                                               TJPI
# 2660                                               TJPI
# 2661                                                NaN
#
#       ... URL do questionário           Endereço de e-mail  \
# 2656  ...                 NaN  viviane.balbuglio@gmail.com
# 2657  ...                 NaN  viviane.balbuglio@gmail.com
# 2658  ...                 NaN  viviane.balbuglio@gmail.com
# 2659  ...                 NaN  viviane.balbuglio@gmail.com
# 2660  ...                 NaN  viviane.balbuglio@gmail.com
# 2661  ...                 NaN  viviane.balbuglio@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 2656                                    Processo físico
# 2657                                    Processo físico
# 2658                                    Processo físico
# 2659                                    Processo físico
# 2660                                    Processo físico
# 2661                            Processo não encontrado
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 2656                                                Não
# 2657                                                Não
# 2658                                                Não
# 2659                                                Não
# 2660                                                Não
# 2661                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
# 2660                                                NaN
# 2661                                                NaN
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 2656                               Buriti dos Lopes         NaN
# 2657                                          Altos         NaN
# 2658                                         Pio IX         NaN
# 2659                                    Esperantina         NaN
# 2660                                            NaN         NaN
# 2661                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 2656                             não se aplica
# 2657                             não se aplica
# 2658                             não se aplica
# 2659                             não se aplica
# 2660                             não se aplica
# 2661                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
# 2660                                                NaN
# 2661                                                NaN
#
#      Estado
# 2656     PI
# 2657     PI
# 2658     PI
# 2659     PI
# 2660     PI
# 2661     PI
#
# [6 rows x 92 columns]

# %%
# 18 - PR


filter = df_final["Estado"] == "PR"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "marimzambom@gmail.com"
df_filt_pr_dv = df_filt[filter_2]


print(df_filt_pr_dv)
# Out:
# Endereço de e-mail
# viviane.balbuglio@gmail.com    135
# marimzambom@gmail.com            6
# dtype: int64
#        Carimbo de data/hora 1 - Nome do pesquisadora  \
# 697 2022-07-05 17:53:52.840    Mariana Morais Zambom
# 698 2022-07-05 18:03:05.620    Mariana Morais Zambom
# 699 2022-07-05 18:17:52.647    Mariana Morais Zambom
# 700 2022-07-05 18:21:49.739    Mariana Morais Zambom
# 701 2022-07-05 18:29:05.746    Mariana Morais Zambom
# 702 2022-07-05 18:36:16.897    Mariana Morais Zambom
#
#     2 - início do preenchimento  \
# 697                    17:50:00
# 698                    18:01:00
# 699                    18:16:00
# 700                    18:20:00
# 701                    18:27:00
# 702                    18:35:00
#
#     3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 697                          0004476-60.2017.8.16.0165
# 698                          0004308-34.2018.8.16.0097
# 699                          0003595-76.2017.8.16.0038
# 700                          0001576-51.2020.8.16.0181
# 701                          0000126-24.2020.8.16.0068
# 702                          0000207-53.2020.8.16.0203
#
#     4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 697                                           1/1/0001
# 698                                           1/1/0001
# 699                                           1/1/0001
# 700                                           1/1/0001
# 701                                           1/1/0001
# 702                                           1/1/0001
#
#     5 - É caso de interesse?  \
# 697                      não
# 698                      não
# 699                      não
# 700                      não
# 701                      não
# 702                      não
#
#     6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 697                                                NaN
# 698                                                NaN
# 699                                                NaN
# 700                                                NaN
# 701                                                NaN
# 702                                                NaN
#
#     7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 697                                                NaN
# 698                                                NaN
# 699                                                NaN
# 700                                                NaN
# 701                                                NaN
# 702                                                NaN
#
#     8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 697                                                NaN
# 698                                                NaN
# 699                                                NaN
# 700                                                NaN
# 701                                                NaN
# 702                                                NaN
#
#     9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 697                                                NaN
# 698                                                NaN
# 699                                                NaN
# 700                                                NaN
# 701                                                NaN
# 702                                                NaN
#
#      ... URL do questionário     Endereço de e-mail  \
# 697  ...                 NaN  marimzambom@gmail.com
# 698  ...                 NaN  marimzambom@gmail.com
# 699  ...                 NaN  marimzambom@gmail.com
# 700  ...                 NaN  marimzambom@gmail.com
# 701  ...                 NaN  marimzambom@gmail.com
# 702  ...                 NaN  marimzambom@gmail.com
#
#     5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 697  Processo digital, encontrado, mas sob restriçã...
# 698  Processo digital, encontrado, mas sob restriçã...
# 699  Processo digital, encontrado, mas sob restriçã...
# 700  Processo digital, encontrado, mas sob restriçã...
# 701  Processo digital, encontrado, mas sob restriçã...
# 702  Processo digital, encontrado, mas sob restriçã...
#
#     3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 697                                                Não
# 698                                                Não
# 699                                                Não
# 700                                                Não
# 701                                                Não
# 702                                                Não
#
#     3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 697                                                NaN
# 698                                                NaN
# 699                                                NaN
# 700                                                NaN
# 701                                                NaN
# 702                                                NaN
#
#     10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 697                                            NaN         NaN
# 698                                            NaN         NaN
# 699                                            NaN         NaN
# 700                                            NaN         NaN
# 701                                            NaN         NaN
# 702                                            NaN         NaN
#
#     5.2. O evento "prisão do agente" ocorreu:  \
# 697                                       NaN
# 698                                       NaN
# 699                                       NaN
# 700                                       NaN
# 701                                       NaN
# 702                                       NaN
#
#     5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 697                                                NaN
# 698                                                NaN
# 699                                                NaN
# 700                                                NaN
# 701                                                NaN
# 702                                                NaN
#
#     Estado
# 697     PR
# 698     PR
# 699     PR
# 700     PR
# 701     PR
# 702     PR
#
# [6 rows x 92 columns]

# %%
# 19 - RJ


filter = df_final["Estado"] == "RJ"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "marimzambom@gmail.com"
df_filt_rj_dv = df_filt[filter_2]


print(df_filt_rj_dv)
# Out:
# Endereço de e-mail
# manuela.valenca@ufpe.br    87
# marimzambom@gmail.com       6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 2436 2022-09-19 10:55:57.954    Mariana Morais Zambom
# 2445 2022-09-15 17:47:45.299    Mariana Morais Zambom
# 2485 2022-09-19 10:57:08.630    Mariana Morais Zambom
# 2486 2022-09-19 10:58:25.359    Mariana Morais Zambom
# 2487 2022-09-19 11:00:04.579    Mariana Morais Zambom
# 2488 2022-09-19 11:01:20.395    Mariana Morais Zambom
#
#      2 - início do preenchimento  \
# 2436                    13:40:00
# 2445                    16:45:00
# 2485                    10:42:00
# 2486                    10:57:00
# 2487                    10:59:00
# 2488                    11:00:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 2436                          0041974-82.2018.8.19.0001
# 2445                          0194710-85.2018.8.19.0001
# 2485                          0024859-21.2018.8.19.0204
# 2486                          0269075-47.2017.8.19.0001
# 2487                          0000127-89.2019.8.19.0058
# 2488                          0000141-70.2021.8.19.0004
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 2436                                2018-02-23 00:00:00
# 2445                                2020-02-05 00:00:00
# 2485                                2018-02-20 00:00:00
# 2486                                2017-10-18 00:00:00
# 2487                                2019-01-14 00:00:00
# 2488                                2021-01-07 00:00:00
#
#                                5 - É caso de interesse?  \
# 2436                                                não
# 2445  não determinado (utilizar essa variável em cas...
# 2485                                                não
# 2486                                                não
# 2487                                                não
# 2488                                                não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 2436                                                NaN
# 2445                                               SEEU
# 2485                                                NaN
# 2486                                                NaN
# 2487                                                NaN
# 2488                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 2436                                                NaN
# 2445                                                1.0
# 2485                                                NaN
# 2486                                                NaN
# 2487                                                NaN
# 2488                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 2436                                                NaN
# 2445                                                1.0
# 2485                                                NaN
# 2486                                                NaN
# 2487                                                NaN
# 2488                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 2436                                                NaN
# 2445                                               TJRJ
# 2485                                                NaN
# 2486                                                NaN
# 2487                                                NaN
# 2488                                                NaN
#
#       ... URL do questionário     Endereço de e-mail  \
# 2436  ...                 NaN  marimzambom@gmail.com
# 2445  ...                 NaN  marimzambom@gmail.com
# 2485  ...                 NaN  marimzambom@gmail.com
# 2486  ...                 NaN  marimzambom@gmail.com
# 2487  ...                 NaN  marimzambom@gmail.com
# 2488  ...                 NaN  marimzambom@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 2436                                    Processo físico
# 2445                                      não se aplica
# 2485                                    Processo físico
# 2486  Processo digital, encontrado, mas sob restriçã...
# 2487  Processo digital, encontrado, mas sob restriçã...
# 2488  Processo digital, encontrado, mas sob restriçã...
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 2436                                                Não
# 2445                                                Não
# 2485                                                Não
# 2486                                                Não
# 2487                                                Não
# 2488                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 2436                                                NSA
# 2445                                                NSA
# 2485                                                NSA
# 2486                                                NSA
# 2487                                                NSA
# 2488                                                NSA
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 2436                                            NaN         NaN
# 2445                                 RIO DE JANEIRO         NaN
# 2485                                            NaN         NaN
# 2486                                            NaN         NaN
# 2487                                            NaN         NaN
# 2488                                            NaN         NaN
#
#               5.2. O evento "prisão do agente" ocorreu:  \
# 2436                                                NaN
# 2445  apenas em outro(s) processo(s) - relatado no p...
# 2485                                                NaN
# 2486                                                NaN
# 2487                                                NaN
# 2488                                                NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 2436                                                NaN
# 2445                         0373922-47.2010.8.19.00011
# 2485                                                NaN
# 2486                                                NaN
# 2487                                                NaN
# 2488                                                NaN
#
#      Estado
# 2436     RJ
# 2445     RJ
# 2485     RJ
# 2486     RJ
# 2487     RJ
# 2488     RJ
#
# [6 rows x 92 columns]

# %%
# 20 - RN


filter = df_final["Estado"] == "RN"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "mairarmachado@hotmail.com"
df_filt_rn_dv = df_filt[filter_2]


print(df_filt_rn_dv)
# Out:
# Endereço de e-mail
# marimzambom@gmail.com        144
# mairarmachado@hotmail.com      6
# anaclaraklink@gmail.com        1
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 3970 2022-11-23 07:58:47.748                    maira
# 3971 2022-11-23 08:11:14.976                    maira
# 3972 2022-11-23 08:57:00.622                    maira
# 3973 2022-11-23 09:36:47.991                    maira
# 3974 2022-11-23 16:32:54.651                    maira
# 3975 2022-11-23 16:36:35.227                    maira
#
#      2 - início do preenchimento  \
# 3970                    07:56:00
# 3971                    07:59:00
# 3972                    08:16:00
# 3973                    09:01:00
# 3974                    15:47:00
# 3975                    16:35:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 3970                          0107693-91.2017.8.20.0106
# 3971                          0800553-34.2021.8.20.5114
# 3972                          0100428-76.2019.8.20.0103
# 3973                          0100103-96.2019.8.20.0137
# 3974                          0108121-63.2018.8.20.0001
# 3975                          0100634-90.2019.8.20.0103
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 3970                                2017-11-29 00:00:00
# 3971                                2021-04-16 00:00:00
# 3972                                2020-09-27 00:00:00
# 3973                                2019-05-21 00:00:00
# 3974                                2018-06-28 00:00:00
# 3975                                2019-07-17 00:00:00
#
#      5 - É caso de interesse?  \
# 3970                      não
# 3971                      não
# 3972       sim: morte externa
# 3973       sim: morte externa
# 3974       sim: morte externa
# 3975                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 3970                                                NaN
# 3971                                                NaN
# 3972                                                PJE
# 3973                                               SEEU
# 3974                                               SEEU
# 3975                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 3970                                                NaN
# 3971                                                NaN
# 3972                                                2.0
# 3973                                                1.0
# 3974                                                1.0
# 3975                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 3970                                                NaN
# 3971                                                NaN
# 3972                                                1.0
# 3973                                                1.0
# 3974                                                1.0
# 3975                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 3970                                                NaN
# 3971                                                NaN
# 3972                                               TJRN
# 3973                                               TJRN
# 3974                                               TJRN
# 3975                                                NaN
#
#       ... URL do questionário         Endereço de e-mail  \
# 3970  ...                 NaN  mairarmachado@hotmail.com
# 3971  ...                 NaN  mairarmachado@hotmail.com
# 3972  ...                 NaN  mairarmachado@hotmail.com
# 3973  ...                 NaN  mairarmachado@hotmail.com
# 3974  ...                 NaN  mairarmachado@hotmail.com
# 3975  ...                 NaN  mairarmachado@hotmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 3970                            Processo não encontrado
# 3971                      Pessoa não passou pela prisão
# 3972                                      não se aplica
# 3973                                      não se aplica
# 3974                                      não se aplica
# 3975                            Processo não encontrado
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 3970                                                Sim
# 3971                                                Não
# 3972                                                Não
# 3973                                                Não
# 3974                                                Não
# 3975                                                Sim
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 3970                                     não encontrado
# 3971                                                NSA
# 3972                                                NSA
# 3973                                                NSA
# 3974                                                NSA
# 3975                                     não encontrado
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 3970                                            NaN         NaN
# 3971                                            NaN         NaN
# 3972                                  Currais Novos         NaN
# 3973                                            NaN         NaN
# 3974                                          Natal         NaN
# 3975                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 3970                                       NaN
# 3971                                       NaN
# 3972     apenas no curso do processo analisado
# 3973     apenas no curso do processo analisado
# 3974     apenas no curso do processo analisado
# 3975                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 3970                                                NaN
# 3971                                                NaN
# 3972                                                NSA
# 3973                                                NSA
# 3974                                                NSA
# 3975                                                NaN
#
#      Estado
# 3970     RN
# 3971     RN
# 3972     RN
# 3973     RN
# 3974     RN
# 3975     RN
#
# [6 rows x 92 columns]

# %%
# 21 - RO


filter = df_final["Estado"] == "RO"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "analiagalvaoalmeida12@gmail.com"
df_filt_ro_dv = df_filt[filter_2]


print(df_filt_ro_dv)
# Out:
# Endereço de e-mail
# anaclaraklink@gmail.com            130
# analiagalvaoalmeida12@gmail.com      6
# anaclaraklink@gmail.ccom             1
# anaclaraklink@gmail.vom              1
# dtype: int64
#        Carimbo de data/hora 1 - Nome do pesquisadora  \
# 630 2022-07-07 16:47:57.708           Ana Lia Galvão
# 631 2022-06-28 14:15:53.467           Ana Lia Galvão
# 632 2022-06-28 14:18:31.844           Ana Lia Galvão
# 633 2022-06-28 14:22:04.987           Ana Lia Galvão
# 634 2022-06-28 14:25:41.131           Ana Lia Galvão
# 646 2022-07-07 16:53:07.086           Ana Lia Galvão
#
#     2 - início do preenchimento  \
# 630                    14:41:00
# 631                    14:12:00
# 632                    14:16:00
# 633                    14:20:00
# 634                    14:23:00
# 646                    14:26:00
#
#     3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 630                          0008989-60.2020.8.22.0501
# 631                          0013736-87.2019.8.22.0501
# 632                          0000510-67.2018.8.22.0010
# 633                          0006590-29.2018.8.22.0501
# 634                          0001366-31.2018.8.22.0010
# 646                          7005186-19.2021.8.22.0014
#
#     4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 630                                2020-10-29 00:00:00
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                NaN
# 646                                2021-07-05 00:00:00
#
#     5 - É caso de interesse?  \
# 630       sim: morte externa
# 631                      NaN
# 632                      NaN
# 633                      NaN
# 634                      NaN
# 646       sim: morte externa
#
#     6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 630                                                PJE
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                NaN
# 646                                                PJE
#
#     7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 630                                                1.0
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                NaN
# 646                                                2.0
#
#     8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 630                                                1.0
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                NaN
# 646                                                1.0
#
#     9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 630                                               TJRO
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                NaN
# 646                                               TJRO
#
#      ... URL do questionário               Endereço de e-mail  \
# 630  ...                 NaN  analiagalvaoalmeida12@gmail.com
# 631  ...                 NaN  analiagalvaoalmeida12@gmail.com
# 632  ...                 NaN  analiagalvaoalmeida12@gmail.com
# 633  ...                 NaN  analiagalvaoalmeida12@gmail.com
# 634  ...                 NaN  analiagalvaoalmeida12@gmail.com
# 646  ...                 NaN  analiagalvaoalmeida12@gmail.com
#
#     5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 630                                                NaN
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                NaN
# 646                                      não se aplica
#
#     3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 630                                                Não
# 631                                                Sim
# 632                                                Sim
# 633                                                Sim
# 634                                                Sim
# 646                                                Não
#
#     3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 630                                                NaN
# 631                          Não encontrado no sistema
# 632                          Não encontrado no sistema
# 633                          Não encontrado no sistema
# 634                          Não encontrado no sistema
# 646                                                NaN
#
#     10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 630                         Comarca de Porto Velho         NaN
# 631                                            NaN         NaN
# 632                                            NaN         NaN
# 633                                            NaN         NaN
# 634                                            NaN         NaN
# 646                             Comarca de Vilhena         NaN
#
#              5.2. O evento "prisão do agente" ocorreu:  \
# 630              apenas no curso do processo analisado
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                NaN
# 646  apenas em outro(s) processo(s) - relatado no p...
#
#     5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 630                                                NaN
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                NaN
# 646                                                 SI
#
#     Estado
# 630     RO
# 631     RO
# 632     RO
# 633     RO
# 634     RO
# 646     RO
#
# [6 rows x 92 columns]

# %%
# 22 - RR


filter = df_final["Estado"] == "RR"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "viviane.balbuglio@gmail.com"
df_filt_rr_dv = df_filt[filter_2]


print(df_filt_rr_dv)
# Out:
# Endereço de e-mail
# anandaendo@usp.br              199
# viviane.balbuglio@gmail.com      6
# ananda@usp.br                    1
# anandaendi@usp.br                1
# dtype: int64
#       Carimbo de data/hora 1 - Nome do pesquisadora  \
# 14 2022-05-25 11:36:32.598        Viviane Balbuglio
# 15 2022-05-25 11:45:06.732        Viviane Balbuglio
# 16 2022-05-25 11:49:11.576        Viviane Balbuglio
# 18 2022-05-25 12:29:48.493        Viviane Balbuglio
# 19 2022-05-25 13:07:08.501        Viviane Balbuglio
# 21 2022-05-25 15:23:02.475        Viviane Balbuglio
#
#    2 - início do preenchimento  \
# 14                    11:31:00
# 15                    11:37:00
# 16                    11:47:00
# 18                    11:50:00
# 19                    12:34:00
# 21                    14:43:00
#
#    3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 14                          0800269-21.2017.8.23.0090
# 15                          0808195-65.2018.8.23.0010
# 16                          0821817-51.2017.8.23.0010
# 18                          1000099-77.2018.8.23.0010
# 19                        0807390-15.2018.8.23.0010\t
# 21                          0819188-70.2018.8.23.0010
#
#    4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 14                                                NaN
# 15                                2018-04-03 00:00:00
# 16                                           1/1/0101
# 18                                2018-02-19 00:00:00
# 19                                2018-03-22 00:00:00
# 21                                2018-07-25 00:00:00
#
#    5 - É caso de interesse?  \
# 14                      não
# 15                      não
# 16                      não
# 18       sim: morte externa
# 19       sim: morte externa
# 21       sim: morte externa
#
#    6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 14                                            PROJUDI
# 15                                            PROJUDI
# 16                                            PROJUDI
# 18                                            PROJUDI
# 19                                            PROJUDI
# 21                                               SEEU
#
#    7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 14                                                 SI
# 15                                                1.0
# 16                                                 SI
# 18                                                1.0
# 19                                                2.0
# 21                                                3.0
#
#    8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 14                                                 SI
# 15                                                1.0
# 16                                                 SI
# 18                                                1.0
# 19                                                1.0
# 21                                                1.0
#
#    9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 14                                               TJRR
# 15                                               TJRR
# 16                                               TJRR
# 18                                               TJRR
# 19                                               TJRR
# 21                                               TJRR
#
#     ... URL do questionário           Endereço de e-mail  \
# 14  ...                 NaN  viviane.balbuglio@gmail.com
# 15  ...                 NaN  viviane.balbuglio@gmail.com
# 16  ...                 NaN  viviane.balbuglio@gmail.com
# 18  ...                 NaN  viviane.balbuglio@gmail.com
# 19  ...                 NaN  viviane.balbuglio@gmail.com
# 21  ...                 NaN  viviane.balbuglio@gmail.com
#
#    5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 14  Processo digital, encontrado, mas sob restriçã...
# 15                      Pessoa não passou pela prisão
# 16  Processo digital, encontrado, mas sob restriçã...
# 18                                                NaN
# 19                                      não se aplica
# 21                                                NaN
#
#    3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 14                                                Sim
# 15                                                Não
# 16                                                Sim
# 18                                                Não
# 19                                                Não
# 21                                                Não
#
#    3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 14  Processo localizado no sistema Projudi TJRR, m...
# 15                                                NaN
# 16  Processo localizado no sistema Projudi do TJRR...
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
#
#    10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 14                                             SI         NaN
# 15                                      Boa Vista         NaN
# 16                                             SI         NaN
# 18                                      Boa Vista         NaN
# 19                                      Boa Vista         NaN
# 21                                      Boa Vista         NaN
#
#    5.2. O evento "prisão do agente" ocorreu:  \
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 18                                       NaN
# 19                                       NaN
# 21                                       NaN
#
#    5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
#
#    Estado
# 14     RR
# 15     RR
# 16     RR
# 18     RR
# 19     RR
# 21     RR
#
# [6 rows x 92 columns]

# %%
# 23 - RS


filter = df_final["Estado"] == "RS"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "manuela.valenca@ufpe.br"
df_filt_rs_dv = df_filt[filter_2]


print(df_filt_rs_dv)
# Out:
# Endereço de e-mail
# anandaendo@usp.br          221
# manuela.valenca@ufpe.br      6
# anandaendo@usp.com           1
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 3994 2022-11-24 21:11:57.534            Manuela Abath
# 3995 2022-11-24 21:12:57.623            Manuela Abath
# 3996 2022-11-24 21:13:43.936            Manuela Abath
# 3997 2022-11-24 21:14:32.273            Manuela Abath
# 3998 2022-11-24 21:16:23.077            Manuela Abath
# 3999 2022-11-24 21:17:16.389            Manuela Abath
#
#      2 - início do preenchimento  \
# 3994                         NaN
# 3995                         NaN
# 3996                         NaN
# 3997                         NaN
# 3998                         NaN
# 3999                         NaN
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 3994                          0005172-80.2018.8.21.0017
# 3995                          0008264-63.2019.8.21.0039
# 3996                          0002451-65.2017.8.21.0123
# 3997                          0000198-53.2020.8.21.0106
# 3998                          0011477-19.2019.8.21.0026
# 3999                          0011715-03.2017.8.21.0028
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 3994                                                NaN
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#      5 - É caso de interesse?  \
# 3994                      não
# 3995                      não
# 3996                      não
# 3997                      não
# 3998                      não
# 3999                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 3994                                                NaN
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 3994                                                NaN
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 3994                                                NaN
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 3994                                                NaN
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#       ... URL do questionário       Endereço de e-mail  \
# 3994  ...                 NaN  manuela.valenca@ufpe.br
# 3995  ...                 NaN  manuela.valenca@ufpe.br
# 3996  ...                 NaN  manuela.valenca@ufpe.br
# 3997  ...                 NaN  manuela.valenca@ufpe.br
# 3998  ...                 NaN  manuela.valenca@ufpe.br
# 3999  ...                 NaN  manuela.valenca@ufpe.br
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 3994                                    Processo físico
# 3995                                    Processo físico
# 3996                                    Processo físico
# 3997                                    Processo físico
# 3998                                    Processo físico
# 3999                                    Processo físico
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 3994                                                Sim
# 3995                                                NaN
# 3996                                                Não
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                Sim
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 3994                                                NaN
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 3994                                            NaN         NaN
# 3995                                            NaN         NaN
# 3996                                            NaN         NaN
# 3997                                            NaN         NaN
# 3998                                            NaN         NaN
# 3999                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 3994                                       NaN
# 3995                                       NaN
# 3996                                       NaN
# 3997                                       NaN
# 3998                                       NaN
# 3999                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 3994                                                NaN
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#      Estado
# 3994     RS
# 3995     RS
# 3996     RS
# 3997     RS
# 3998     RS
# 3999     RS
#
# [6 rows x 92 columns]

# %%
# 24 - SC

filter = df_final["Estado"] == "SC"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "marimzambom@gmail.com"
df_filt_sc_dv = df_filt[filter_2]


print(df_filt_sc_dv)
# Out:
# Endereço de e-mail
# mairarmachado@hotmail.com    164
# marimzambom@gmail.com          6
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 3224 2022-11-05 11:50:11.351    Mariana Morais Zambom
# 3225 2022-11-05 15:10:10.839    Mariana Morais Zambom
# 3226 2022-11-05 14:54:50.255    Mariana Morais Zambom
# 3227 2022-11-05 17:37:11.664    Mariana Morais Zambom
# 3228 2022-11-05 18:23:24.063    Mariana Morais Zambom
# 3229 2022-11-05 18:44:38.994    Mariana Morais Zambom
#
#      2 - início do preenchimento  \
# 3224                    11:20:00
# 3225                    14:00:00
# 3226                    13:50:00
# 3227                    17:00:00
# 3228                    17:37:00
# 3229                    18:24:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 3224                          0000648-31.2017.8.24.0069
# 3225                          0008927-21.2017.8.24.0064
# 3226                          0002783-38.2018.8.24.0018
# 3227                          5004755-44.2019.8.24.0075
# 3228                          5002333-44.2020.8.24.0081
# 3229                          0000938-93.2019.8.24.0063
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 3224                                2017-04-03 00:00:00
# 3225                                2017-10-06 00:00:00
# 3226                                2018-03-28 00:00:00
# 3227                                2019-11-22 00:00:00
# 3228                                2020-08-07 00:00:00
# 3229                                2019-09-04 00:00:00
#
#      5 - É caso de interesse?  \
# 3224                      não
# 3225       sim: morte externa
# 3226       sim: morte externa
# 3227                      não
# 3228       sim: morte externa
# 3229                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 3224                                                NaN
# 3225                                             E-proc
# 3226                                             E-proc
# 3227                                                NaN
# 3228                                             E-proc
# 3229                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 3224                                                NaN
# 3225                                                1.0
# 3226                                                1.0
# 3227                                                NaN
# 3228                                                1.0
# 3229                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 3224                                                NaN
# 3225                                                1.0
# 3226                                                1.0
# 3227                                                NaN
# 3228                                                1.0
# 3229                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 3224                                                NaN
# 3225                                         TJSC (Saj)
# 3226                                         TJSC (Saj)
# 3227                                                NaN
# 3228                                         TJSC (Saj)
# 3229                                                NaN
#
#       ... URL do questionário     Endereço de e-mail  \
# 3224  ...                 NaN  marimzambom@gmail.com
# 3225  ...                 NaN  marimzambom@gmail.com
# 3226  ...                 NaN  marimzambom@gmail.com
# 3227  ...                 NaN  marimzambom@gmail.com
# 3228  ...                 NaN  marimzambom@gmail.com
# 3229  ...                 NaN  marimzambom@gmail.com
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 3224                      Pessoa não passou pela prisão
# 3225                                      não se aplica
# 3226                                      não se aplica
# 3227                      Pessoa não passou pela prisão
# 3228                                      não se aplica
# 3229                      Pessoa não passou pela prisão
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 3224                                                Não
# 3225                                                Não
# 3226                                                Não
# 3227                                                Não
# 3228                                                Não
# 3229                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 3224                                                NSA
# 3225                                                NSA
# 3226                                                NSA
# 3227                                                NSA
# 3228                                                NSA
# 3229                                                NSA
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 3224                                            NaN         NaN
# 3225                                       São José         NaN
# 3226                                        Chapecó         NaN
# 3227                                            NaN         NaN
# 3228                                          Xaxim         NaN
# 3229                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 3224                                       NaN
# 3225                                     ambos
# 3226                                     ambos
# 3227                                       NaN
# 3228     apenas no curso do processo analisado
# 3229                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 3224                                                NaN
# 3225                          0011662-95.2015.8.24.0064
# 3226  0000890-12.2018.8.24.0018; 0001667-65.2016.8.2...
# 3227                                                NaN
# 3228                                                NSA
# 3229                                                NaN
#
#      Estado
# 3224     SC
# 3225     SC
# 3226     SC
# 3227     SC
# 3228     SC
# 3229     SC
#
# [6 rows x 92 columns]

# %%
# 25 - SE

filter = df_final["Estado"] == "SE"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "anandaendo@usp.br"
df_filt_se_dv = df_filt[filter_2]


print(df_filt_se_dv)
# Out:
# Endereço de e-mail
# anaclaraklink@gmail.com            83
# anandaendo@usp.br                   6
# analiagalvaoalmeida12@gmail.com     1
# dtype: int64
#        Carimbo de data/hora 1 - Nome do pesquisadora  \
# 650 2022-06-28 18:46:44.657              Ananda Endo
# 653 2022-06-28 19:44:55.513              Ananda Endo
# 790 2022-07-12 13:55:35.519              Ananda Endo
# 792 2022-07-12 15:11:25.629              Ananda Endo
# 796 2022-07-12 15:57:58.457              Ananda Endo
# 797 2022-07-12 16:09:50.895              Ananda Endo
#
#     2 - início do preenchimento  \
# 650                    18:45:00
# 653                    18:47:00
# 790                    13:01:00
# 792                    15:10:00
# 796                    15:22:00
# 797                    16:05:00
#
#     3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 650                          0000460-40.2019.8.25.0069
# 653                          0001042-35.2021.8.25.0048
# 790                          0000194-03.2021.8.25.0063
# 792                          0000336-91.2017.8.25.0048
# 796                          0000745-68.2019.8.25.0025
# 797                          0002869-06.2017.8.25.0000
#
#     4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 650                                                NaN
# 653                                2021-04-30 00:00:00
# 790                                2021-01-28 00:00:00
# 792                                2017-02-10 00:00:00
# 796                                2019-05-14 00:00:00
# 797                                                NaN
#
#                               5 - É caso de interesse?  \
# 650                                                NaN
# 653                                 sim: morte externa
# 790  não determinado (utilizar essa variável em cas...
# 792                                                não
# 796                                 sim: morte externa
# 797                                                NaN
#
#     6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 650                                                NaN
# 653  Sistema de pesquisa próprio do tribunal estadu...
# 790  Sistema de pesquisa próprio do tribunal estadu...
# 792                                                NaN
# 796  Sistema de pesquisa próprio do tribunal estadu...
# 797                                                NaN
#
#     7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 650                                                NaN
# 653                                                1.0
# 790                                                1.0
# 792                                                NaN
# 796                                                1.0
# 797                                                NaN
#
#     8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 650                                                NaN
# 653                                                1.0
# 790                                                1.0
# 792                                                NaN
# 796                                                1.0
# 797                                                NaN
#
#     9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 650                                                NaN
# 653                                               TJSE
# 790                                               TJSE
# 792                                                NaN
# 796                                               TJSE
# 797                                                NaN
#
#      ... URL do questionário Endereço de e-mail  \
# 650  ...                 NaN  anandaendo@usp.br
# 653  ...                 NaN  anandaendo@usp.br
# 790  ...                 NaN  anandaendo@usp.br
# 792  ...                 NaN  anandaendo@usp.br
# 796  ...                 NaN  anandaendo@usp.br
# 797  ...                 NaN  anandaendo@usp.br
#
#     5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 650                                                NaN
# 653                                      não se aplica
# 790                                      não se aplica
# 792                      Pessoa não passou pela prisão
# 796                                      não se aplica
# 797                                                NaN
#
#     3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 650                                                Sim
# 653                                                Não
# 790                                                Não
# 792                                                Não
# 796                                                Não
# 797                                                Sim
#
#     3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 650                                 Segredo de Justiça
# 653                                                NSA
# 790                                                NSA
# 792                                                NSA
# 796                                                NSA
# 797                            Processo não encontrado
#
#     10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 650                                            NaN         NaN
# 653                        Nossa Senhora da Glória         NaN
# 790                                        Propriá         NaN
# 792                                            NaN         NaN
# 796                                  Cristinápolis         NaN
# 797                                            NaN         NaN
#
#              5.2. O evento "prisão do agente" ocorreu:  \
# 650                                                NaN
# 653                                                NaN
# 790  apenas em outro(s) processo(s) - relatado no p...
# 792                                                NaN
# 796              apenas no curso do processo analisado
# 797                                                NaN
#
#     5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 650                                                NaN
# 653                                                NaN
# 790                                                 SI
# 792                                                NaN
# 796                                                NSA
# 797                                                NaN
#
#     Estado
# 650     SE
# 653     SE
# 790     SE
# 792     SE
# 796     SE
# 797     SE
#
# [6 rows x 92 columns]

# %%
# 26 - SP

filter = df_final["Estado"] == "SP"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "manuela.valenca@ufpe.br"
df_filt_sp_dv = df_filt[filter_2]

print(df_filt_sp_dv)
# Out:
# Endereço de e-mail
# viviane.balbuglio@gmail.com    59
# anaclaraklink@gmail.com        29
# manuela.valenca@ufpe.br         6
# anandaendo@usp.br               1
# dtype: int64
#         Carimbo de data/hora 1 - Nome do pesquisadora  \
# 2198 2022-09-05 20:29:26.699    Manuela Abath Valença
# 2199 2022-09-05 20:48:40.292            Manuela Abath
# 2200 2022-09-05 20:59:29.722            Manuela Abath
# 2201 2022-09-05 21:13:13.268            Manuela Abath
# 2202 2022-09-05 21:16:41.716            Manuela Abath
# 2203 2022-09-05 21:45:11.542            Manuela Abath
#
#      2 - início do preenchimento  \
# 2198                    20:20:00
# 2199                    20:42:00
# 2200                    20:58:00
# 2201                    21:01:00
# 2202                    21:16:00
# 2203                    21:44:00
#
#      3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 2198                          0003635-29.2020.8.26.0344
# 2199                          0010705-05.2017.8.26.0635
# 2200                          0000132-70.2018.8.26.0505
# 2201                          1500776-10.2020.8.26.0491
# 2202                          0005051-16.2017.8.26.0642
# 2203                          1500934-17.2019.8.26.0292
#
#      4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 2198                                2015-10-13 00:00:00
# 2199                                2017-12-04 00:00:00
# 2200                                                NaN
# 2201                                                NaN
# 2202                                                NaN
# 2203                                                NaN
#
#      5 - É caso de interesse?  \
# 2198       sim: morte externa
# 2199       sim: morte externa
# 2200                      NaN
# 2201                      não
# 2202                      não
# 2203                      não
#
#      6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 2198                                              E-SAJ
# 2199                                              E-SAJ
# 2200                                                NaN
# 2201                                                NaN
# 2202                                                NaN
# 2203                                                NaN
#
#      7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 2198                                                1.0
# 2199                                                1.0
# 2200                                                NaN
# 2201                                                NaN
# 2202                                                NaN
# 2203                                                NaN
#
#      8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 2198                                                1.0
# 2199                                                1.0
# 2200                                                NaN
# 2201                                                NaN
# 2202                                                NaN
# 2203                                                NaN
#
#      9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 2198                                         TJSP (Saj)
# 2199                                         TJSP (Saj)
# 2200                                                NaN
# 2201                                                NaN
# 2202                                                NaN
# 2203                                                NaN
#
#       ... URL do questionário       Endereço de e-mail  \
# 2198  ...                 NaN  manuela.valenca@ufpe.br
# 2199  ...                 NaN  manuela.valenca@ufpe.br
# 2200  ...                 NaN  manuela.valenca@ufpe.br
# 2201  ...                 NaN  manuela.valenca@ufpe.br
# 2202  ...                 NaN  manuela.valenca@ufpe.br
# 2203  ...                 NaN  manuela.valenca@ufpe.br
#
#      5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 2198                                      não se aplica
# 2199                                      não se aplica
# 2200                                                NaN
# 2201                      Pessoa não passou pela prisão
# 2202                      Pessoa não passou pela prisão
# 2203                      Pessoa não passou pela prisão
#
#      3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 2198                                                Não
# 2199                                                Não
# 2200                                                Sim
# 2201                                                Não
# 2202                                                Não
# 2203                                                Não
#
#      3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 2198                                                NaN
# 2199                                                NSA
# 2200  Não se trata de extinção de punibilidade pela ...
# 2201                                                NaN
# 2202                                                NaN
# 2203                                                NaN
#
#      10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 2198                                        Marília         NaN
# 2199                                      São Paulo         NaN
# 2200                                            NaN         NaN
# 2201                                            NaN         NaN
# 2202                                            NaN         NaN
# 2203                                            NaN         NaN
#
#      5.2. O evento "prisão do agente" ocorreu:  \
# 2198     apenas no curso do processo analisado
# 2199     apenas no curso do processo analisado
# 2200                                       NaN
# 2201                                       NaN
# 2202                                       NaN
# 2203                                       NaN
#
#      5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 2198                                                 SI
# 2199                                                NSA
# 2200                                                NaN
# 2201                                                NaN
# 2202                                                NaN
# 2203                                                NaN
#
#      Estado
# 2198     SP
# 2199     SP
# 2200     SP
# 2201     SP
# 2202     SP
# 2203     SP
#
# [6 rows x 92 columns]

# %%
# 27 - TO

filter = df_final["Estado"] == "TO"
df_filt = df_final[filter]

print(df_filt.value_counts(subset = ['Endereço de e-mail']))

filter_2 = df_filt['Endereço de e-mail'] == "viviane.balbuglio@gmail.com"
df_filt_to_dv = df_filt[filter_2]


print(df_filt_to_dv)
# Out:
# Endereço de e-mail
# anaclaraklink@gmail.com        130
# viviane.balbuglio@gmail.com      6
# anaclaraklink@gmail.con          2
# dtype: int64
#        Carimbo de data/hora 1 - Nome do pesquisadora  \
# 295 2022-06-12 14:24:34.849        Viviane Balbuglio
# 296 2022-06-12 14:54:01.416        Viviane Balbuglio
# 298 2022-06-12 15:02:56.415        Viviane Balbuglio
# 299 2022-06-12 15:11:19.032        Viviane Balbuglio
# 317 2022-06-13 14:44:44.127        Viviane Balbuglio
# 318 2022-06-13 14:50:56.887        Viviane Balbuglio
#
#     2 - início do preenchimento  \
# 295                    14:20:00
# 296                    14:25:00
# 298                    15:01:00
# 299                    15:03:00
# 317                    14:33:00
# 318                    14:45:00
#
#     3 - Número do processo (se possível, colocar no padrão CNJ com pontos e traço. EX: 1000347-33.2021.8.26.0114):  \
# 295                          0000652-20.2019.8.27.2719
# 296                          0007862-23.2018.8.27.2731
# 298                          0009533-40.2020.8.27.2722
# 299                          0001272-03.2017.8.27.2719
# 317                          0005257-47.2017.8.27.2729
# 318                          0001142-63.2019.8.27.2712
#
#     4 - Data da distribuição (colocar 010101 - para casos "sem informações")  \
# 295                                2019-04-22 00:00:00
# 296                                2018-11-26 00:00:00
# 298                                                NaN
# 299                                2017-09-12 00:00:00
# 317                                2017-02-22 00:00:00
# 318                                2019-07-18 00:00:00
#
#                               5 - É caso de interesse?  \
# 295                                                não
# 296  não determinado (utilizar essa variável em cas...
# 298                                                não
# 299                                                não
# 317                                                não
# 318                                                não
#
#     6 - Qual foi o sistema de acesso utilizado para acessar o processo?  \
# 295                                             E-proc
# 296                                             E-proc
# 298                                                NaN
# 299                                             E-proc
# 317                                             E-proc
# 318                                             E-proc
#
#     7 - Quantas pessoas estão respondendo pelo mesmo processo?  \
# 295                                                1.0
# 296                                                1.0
# 298                                                NaN
# 299                                                1.0
# 317                                                2.0
# 318                                                1.0
#
#     8 - Quantas pessoas que respondiam ao processo faleceram (considerando as informações do processo)?  \
# 295                                                1.0
# 296                                                1.0
# 298                                                NaN
# 299                                                1.0
# 317                                                1.0
# 318                                                1.0
#
#     9 - Nome do tribunal que abrange o foro/comarca/subseção onde o processo foi distribuído  \
# 295                                               TJTO
# 296                                               TJTO
# 298                                                NaN
# 299                                               TJTO
# 317                                               TJTO
# 318                                               TJTO
#
#      ... URL do questionário           Endereço de e-mail  \
# 295  ...                 NaN  viviane.balbuglio@gmail.com
# 296  ...                 NaN  viviane.balbuglio@gmail.com
# 298  ...                 NaN  viviane.balbuglio@gmail.com
# 299  ...                 NaN  viviane.balbuglio@gmail.com
# 317  ...                 NaN  viviane.balbuglio@gmail.com
# 318  ...                 NaN  viviane.balbuglio@gmail.com
#
#     5.1 - Se a resposta anterior foi não, qual a razão da eliminação ?  \
# 295                      Pessoa não passou pela prisão
# 296                                      não se aplica
# 298                            Processo não encontrado
# 299                      Pessoa não passou pela prisão
# 317                      Pessoa não passou pela prisão
# 318                      Pessoa não passou pela prisão
#
#     3.1 - Caso descartado antecipadamente? (por motivos como "não encontrado no sistema", "número inválido", etc)  \
# 295                                                Não
# 296                                                Não
# 298                                                Sim
# 299                                                Não
# 317                                                Não
# 318                                                Não
#
#     3.1.1. Em caso de resposta "sim" na pergunta anterior, informe o motivo:  \
# 295                                                NaN
# 296                                                NaN
# 298  Processo não localizado, provavelmente está em...
# 299                                                NaN
# 317                                                NaN
# 318                                                NaN
#
#     10.1 - Comarca onde o processo foi distribuído Unnamed: 88  \
# 295                            Formoso do Araguaia         NaN
# 296                        Paraíso do Tocantins            NaN
# 298                                            NaN         NaN
# 299                           Formoso do Araguaia          NaN
# 317                                         Palmas         NaN
# 318                             Axixá do Tocantins         NaN
#
#     5.2. O evento "prisão do agente" ocorreu:  \
# 295                                       NaN
# 296                                       NaN
# 298                                       NaN
# 299                                       NaN
# 317                                       NaN
# 318                                       NaN
#
#     5.3. Caso haja informação sobre a prisão em outro processo, indique o(s) número(s) - se houver mais de um, separe por ponto e vírgula ";".  \
# 295                                                NaN
# 296                                                NaN
# 298                                                NaN
# 299                                                NaN
# 317                                                NaN
# 318                                                NaN
#
#     Estado
# 295     TO
# 296     TO
# 298     TO
# 299     TO
# 317     TO
# 318     TO
#
# [6 rows x 92 columns]

# %%
df_final_aj = pd.concat([df_filt_ac_dv,df_filt_al_dv,df_filt_ap_dv,df_filt_am_dv,df_filt_ba_dv,df_filt_ce_dv,df_filt_df_dv,df_filt_es_dv,df_filt_go_dv,df_filt_ma_dv,df_filt_ms_dv,df_filt_mg_dv,df_filt_mt_dv,df_filt_pa_dv,df_filt_pb_dv,df_filt_pe_dv,df_filt_pi_dv,df_filt_pr_dv,df_filt_rj_dv,df_filt_rn_dv,df_filt_ro_dv,df_filt_rr_dv,df_filt_rs_dv,df_filt_sc_dv,df_filt_se_dv,df_filt_sp_dv,df_filt_to_dv],ignore_index = True)
print(len(df_final_aj))
# Out:
# 158

# %%
list_num = ['50009375620188210058','0140359-45.2017.8.21.0001',"0401059-48.2017.8.07.0015","0000958-09.2019.8.15.0751",
            '0002262-74.2017.8.17.4011','0000324-70.2019.8.17.4012','000096617.2017.8.17.4011','1003334-41.2019.8.17.4001',
            '0700016-55.2017.8.18.0028','0100483-93.2020.8.20.0102','1000389-24.2020.8.23.0010','1000321-11.2019.8.23.0010',
            '1000426-85.2019.8.23.0010','1000252-13.2018.8.23.0010','1000207-09.2018.8.23.0010','1000165-57.2018.8.23.0010',
            '1000650-23.2019.8.23.0010','0004423-73.2017.8.25.0086']
list_vl = ["sim: morte externa","sim: morte externa","sim: morte interna","sim: morte interna",
           "sim: morte interna","sim: morte interna","sim: morte interna","sim: morte interna",
           "sim: morte interna","sim: morte interna","sim: morte interna","sim: morte interna",
           "sim: morte interna","sim: morte interna"]

for item in numeros:
  if str(item) in list_num:
    print(item)


## não tem nenhum dessa lista!!
# Out:
# 1000389-24.2020.8.23.0010
# 1000321-11.2019.8.23.0010
# 1000426-85.2019.8.23.0010
# 1000252-13.2018.8.23.0010
# 1000207-09.2018.8.23.0010
# 0004423-73.2017.8.25.0086
# 1000165-57.2018.8.23.0010
# 1000650-23.2019.8.23.0010
# 0002262-74.2017.8.17.4011
# 0000324-70.2019.8.17.4012
# 000096617.2017.8.17.4011
# 000096617.2017.8.17.4011
# 1003334-41.2019.8.17.4001
# 0401059-48.2017.8.07.0015
# 0000958-09.2019.8.15.0751
# 0140359-45.2017.8.21.0001
# 50009375620188210058
# 0100483-93.2020.8.20.0102
# 0700016-55.2017.8.18.0028

# %% [markdown]
# abrindo a planilha final

# %%
df_final_dt = pd.read_excel("/content/drive/My Drive/codigos_colab/df_final_ajust.xlsx")

# %%
numeros_aj = df_final_aj.iloc[:,3].to_list()
numeros_dt = df_final_dt.iloc[:,3].to_list()

# %%
# limpando os números
rgx_lp = re.compile("[^0-9]")

nm_limpos_2 = []
for n in range(len(numeros_aj)):
    # print(numeros_aj[n])
    nm = re.sub(rgx_lp,"",numeros_aj[n])
    # print(nm.strip())
    nm_limpos_2.append(nm.strip())



nm_limpos_f = []
for n in range(len(numeros_dt)):
    # print(numeros_dt[n])
    nm = re.sub(rgx_lp,"",numeros_dt[n])
    # print(nm.strip())
    nm_limpos_f.append(nm.strip())

# %%
print(nm_limpos_2)
print(len(nm_limpos_2))
print(nm_limpos_f)
print(len(nm_limpos_f))
# Out:
# ['08014539720178010001', '90000069520208010017', '00021556620198010014', '00041063720198010001', '00095304720198010070', '0043035520208010001', '07017162020178020058', '00081601920198020001', '00001588120218020036', '07091324520198020001', '00044511020188020001', '07068355920178020058', '00027695320198030002', '00000900920218030003', '00008784220208030008', '00145460420208030001', '00020201820198030008', '00113964620198030002', '06149400320188040001', '00004442720188046400', '02370612720178040001', '2425772820178040001', '00003704220208043800', '2049761720198040001', '81462909220218050001', '05013065720188050112', '80002109520218050087', '03025382720178050079', '03034857020188050039', '05000575820208050126', '01229117620178060001', '80034186120208060001', '00001043020178060203', '00170880720178060101', '00029935620178060073', '00021646120198060055', '04018738920198070015', '00060557220178070010', '00002168120178070005', '00002168120178070005', '00022238120198070003', '00046647620178070012', '04024737620208070015', '20005281620218080050', '00013481420178080049', '00000055420198080035', '00264662420198080048', '00002468420208080005', '00024564420178080028', '01343432020198090137', '00065476820198090162', '00001643620198100004', '00017780520198100060', '00089629220198100001', '', '00000097320198100023', '00018974320178100057', '00072114720188120002', '00002059020198120054', '00029354320188120011', '00046218320178120018', '00079253720198120110', '00025961220178120014', '00422607720208130738', '00008775720178130243', '00272425320188130134', '44000140320198130338', '00143673720218130040', '00244993120208130480', '10003936320218110009', '00050047920198110063', '10013226720208110030', '10179277220208110003', '20000856620198110013', '00018095920178110030', '00081342020178140401', '00062867320208140051', '00007693820198140014', '08007074920208140104', '30037620198140051', '00159002720178140401', '80010160320198152002', '70035254820178150011', '00004311920188150581', '00000747020188150021', '00005435020198150161', '00004311920188150581', '00447925920188170810', '00004057120198171020', '00003187520198170710', '00008142420188170360', '00191788820178170001', '00004149520178180043', '00000180820188180036', '00002286620188180066', '00003453720208180050', '00029511220178180028', '00000677920178180005', '00044766020178160165', '00043083420188160097', '00035957620178160038', '00015765120208160181', '00001262420208160068', '00002075320208160203', '00419748220188190001', '01947108520188190001', '00248592120188190204', '02690754720178190001', '00001278920198190058', '00001417020218190004', '01076939120178200106', '08005533420218205114', '01004287620198200103', '01001039620198200137', '01081216320188200001', '01006349020198200103', '00089896020208220501', '00137368720198220501', '00005106720188220010', '00065902920188220501', '00013663120188220010', '70051861920218220014', '08002692120178230090', '08081956520188230010', '08218175120178230010', '10000997720188230010', '08073901520188230010', '08191887020188230010', '00051728020188210017', '00082646320198210039', '00024516520178210123', '00001985320208210106', '00114771920198210026', '00117150320178210028', '00006483120178240069', '00089272120178240064', '00027833820188240018', '50047554420198240075', '50023334420208240081', '00009389320198240063', '00004604020198250069', '00010423520218250048', '00001940320218250063', '00003369120178250048', '00007456820198250025', '00028690620178250000', '00036352920208260344', '00107050520178260635', '00001327020188260505', '15007761020208260491', '00050511620178260642', '15009341720198260292', '00006522020198272719', '00078622320188272731', '00095334020208272722', '00012720320178272719', '00052574720178272729', '00011426320198272712']
# 158
# ['90012553220208010001', '00012007420198010001', '00106302120178010001', '00011311020178010002', '00045495620178010001', '00007262920178010016', '00083030620178010001', '00001642020178010016', '00085519820198010001', '00005693120188010013', '00028335420188010002', '00043348020178010001', '00003817220178010013', '00105591920178010001', '00007547120198010001', '00025803520198010001', '00003812220198010007', '00016756420188010001', '00109512220188010001', '00099478120178010001', '00055111120198010001', '00012137120188010013', '00071032720188010001', '00128531020188010001', '00041046420198010002', '00029337520198010001', '00000096220178010001', '00021556620198010014', '90000304120208010012', '00008272520198010007', '00012936920178010013', '00057588920198010001', '00009127920178010007', '00038532020178010001', '00047334120198010001', '00053974320178010001', '00011951720178010003', '08000049520178010004', '05001450220178010001', '00003201320188010003', '00011836720218010001', '00088158620178010001', '00072602920208010001', '00022301520178010002', '06419987820188040001', '02112534920198040001', '06388421920178040001', '02030024220198040001', '06712794520198040001', '02159270720188040001', '06127896420188040001', '06347956520188040001', '06370491120188040001', '02358484920188040001', '02001943520178040001', '02160258920188040001', '06469991020198040001', '02422230320178040001', '00000345420188043300', '02190674920188040001', '02467751120178040001', '06000481420218046200', '06107852020198040001', '02346882320178040001', '02332497420178040001', '06128878320178040001', '06407276320208040001', '06727847120198040001', '06018165020188040001', '02282109620178040001', '02282109620178040001', '00767302820198090174', '00728681720178090175', '01289021620188090130', '70000460720218090130', '00394392220198090100', '01186626520188090130', '50512694720198090051', '00394479620198090100', '70000984920208090029', '01090292720188090034', '00031005920178160126', '08073901520188230010', '10005105720178230010', '10009499720198230010', '10001347120178230010', '10002738620188230010', '10003892420208230010', '10003211120198230010', '10004268520198230010', '08331110320178230010', '10005648120218230010', '10002070920188230010', '08004886620178230047', '10000491720198230010', '08079066420208230010', '10005451220208230010', '10002455520178230010', '10003566820198230010', '10001655720188230010', '10002256420178230010', '08191887020188230010', '10002629120178230010', '10000058120198230047', '10001880320188230010', '10004291120178230010', '10000039620178230010', '10006502320198230010', '50015969620208250086', '50012201320208250086', '00005006820198250086', '50006312120208250086', '50000712320208250040', '00028690620178250086', '00007016020198250086', '50007126720208250086', '00012873420188250086', '00029484820188250086', '50008731420198250086', '00118265720178250001', '00064311420198250034', '00064311420198250034', '00742064820198250001', '00436919820178250001', '00021710220178250053', '00027818420188250036', '00044721720178250086', '00019371820178250086', '00039037920188250086', '00015575820188250086', '00001097120208250024', '50003359620208250086', '00044237320178250086', '00022051720178250072', '00240427920198250001', '00077670520178272706', '00005333920178272716', '00024753320188272729', '00020288020208272727', '00015839620198272727', '00007744520198272715', '00403945620188272729', '00162078120188272729', '00199154220188272729', '00021988320198272728', '00028385820208272726', '00047002120218272729', '00136436620178272729', '50001176020208272722', '00072822720178272731', '00057868020188272713', '00028640620208010002', '00011256420218010001', '00055989520188010002', '00008931420198010004', '00015031320178010081', '00013074320178010081', '08005055820178010001', '00001253420188010001', '00030552520188010001', '00061722420188010001', '00017032020178010081', '07163938820198010001', '08005548220198010081', '00017961620178010070', '07109298320198010001', '07014136820218 ...
# 4011

# %%
indexes_dt = []
indexes_aj = []
for z in range(len(nm_limpos_f)):
  if nm_limpos_f[z] in nm_limpos_2:
    indexes_dt.append(z)
    idx_aj = nm_limpos_2.index(nm_limpos_f[z])
    indexes_aj.append(idx_aj)

# %% [markdown]
# indices de números iguais

# %%
print(indexes_dt)
print(len(indexes_dt))
print(indexes_aj)
print(len(indexes_aj))
# Out:
# [27, 82, 101, 199, 240, 241, 242, 243, 244, 245, 321, 364, 366, 375, 416, 503, 518, 534, 568, 597, 609, 645, 671, 782, 783, 784, 785, 786, 787, 854, 906, 930, 984, 985, 986, 987, 988, 1336, 1379, 1385, 1431, 1620, 1624, 1630, 1662, 1686, 1737, 1744, 1749, 1787, 1862, 1898, 1922, 1999, 2018, 2077, 2081, 2110, 2139, 2220, 2221, 2222, 2223, 2224, 2377, 2392, 2441, 2457, 2458, 2476, 2720, 2748, 2776, 2834, 2835, 2836, 2837, 2838, 2839, 2921, 2922, 2923, 2924, 2925, 2926, 2927, 3099, 3177, 3206, 3210, 3334, 3368, 3369, 3370, 3371, 3372, 3373, 3589, 3590, 3591, 3592, 3593, 3594, 3758, 3778, 3812, 3855, 3886, 3905, 3911, 3997]
# 111
# [2, 126, 127, 3, 6, 7, 8, 9, 10, 11, 14, 17, 16, 12, 18, 20, 22, 29, 24, 27, 26, 28, 25, 30, 32, 33, 34, 31, 35, 42, 37, 43, 47, 46, 45, 43, 44, 53, 51, 52, 56, 61, 62, 60, 59, 66, 73, 74, 69, 72, 70, 71, 71, 80, 78, 75, 80, 77, 76, 81, 82, 83, 84, 85, 89, 91, 87, 90, 90, 88, 102, 103, 98, 104, 106, 107, 105, 108, 109, 110, 111, 111, 112, 113, 114, 115, 121, 117, 122, 125, 123, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 144, 145, 151, 146, 149, 156, 154, 153]
# 111

# %% [markdown]
# comparando os dois DF

# %%
# taxa de divergência ajustada

pd.set_option("max_rows", None)
idx_questoes = [5,85]
diverg_coleta = 0
descarte = 0
nao_descarte = 0
for n,j in zip(indexes_dt,indexes_aj):
  df_1 = df_final_dt.iloc[n,:-26]
  df_2 = df_final_aj.iloc[j,:-5]
  # print(df_1[85])
  # print(df_2[85])
  # print(len(df_1))
  # print(len(df_2))

  # z =input("")
  # dropar Estado e unamed 88
  difference_locations = np.where(df_1 != df_2)
  # print(list(difference_locations[0]))
  # z = input("")
  if df_1[5] == "não" and df_2[5] == "não":
    list_dif = list(difference_locations[0])
    descarte += 1
    # print(list_dif)    
    # print(df_1[3],df_1[1] )
    # print(df_2[3],df_2[1])
    # print()
    # diverg_desc += 1
    # for it in list_dif:
    #   if it in idx_descart:
    #     print(df_1[4])
    #     print(df_2[4])
    #     # print(df_1[5])
    #     # print(df_2[5])
    #     trat_1 = str(df_1[it]).strip()
    #     trat_2 = str(df_2[it]).strip()
    #     print()
    #     if str(trat_1) == str(trat_2):
    #       print("é igual depois do tratamento")
    #     else:
    #       diverg_desc += 1
    # z = input("")

  else:
    list_dif = list(difference_locations[0])
    # print(df_1[3],df_1[1] )
    # print(df_2[3],df_2[1])
    # print()
    nao_descarte +=1
    # print(df_1[1])
    # print(df_2[1])
    
    for it in list_dif:
      # print(df_1[3])
      # print(df_2[3])
      if it in idx_questoes:
        # print(it)
        # print(df_1[it])
        # print(df_2[it])
        diverg_coleta += 1
        # z = input("")

  # z= input("")

print("não descarte:",nao_descarte)
print("descarte:", descarte)
# print("a divergencia do descarte é :", diverg_desc)
print("a possibilidade de erro nos coletados é", len(idx_questoes)*68)
print("a possibilidade de erro total é", (len(idx_questoes)*68)+43)
print("o total da divergência é", diverg_coleta)
tx_diverg = (diverg_coleta*100)/179
print("a taxa de divergência do é:",tx_diverg)
# Out:
# não descarte: 68
# descarte: 43
# a possibilidade de erro nos coletados é 136
# a possibilidade de erro total é 179
# o total da divergência é 45
# a taxa de divergência do é: 25.139664804469273

# %%
# taxa de divergência 

# pd.set_option("max_rows", None)
# idx_questoes = [4,5,6,7,8,9,10,12,17,18,19,20,21,23,26,27,29,31,32,33,40,41,44,45,46,47,49,54,58,59,60,62,66,69,73,76]
# diverg_coleta = 0
# descarte = 0
# nao_descarte = 0
# for n,j in zip(indexes_dt,indexes_aj):
#   df_1 = df_final_dt.iloc[n,:-26]
#   df_2 = df_final_aj.iloc[j,:-5]
#   # print(df_1)
#   # print(df_2)
#   # z =input("")
#   # dropar Estado e unamed 88
#   difference_locations = np.where(df_1 != df_2)
#   # print(list(difference_locations[0]))
#   # z = input("")
#   if df_1[5] == "não" and df_2[5] == "não":
#     list_dif = list(difference_locations[0])
#     descarte += 1
#     # print(list_dif)    
#     # print(df_1[3],df_1[1] )
#     # print(df_2[3],df_2[1])
#     # print()
#     # diverg_desc += 1
#     # for it in list_dif:
#     #   if it in idx_descart:
#     #     print(df_1[4])
#     #     print(df_2[4])
#     #     # print(df_1[5])
#     #     # print(df_2[5])
#     #     trat_1 = str(df_1[it]).strip()
#     #     trat_2 = str(df_2[it]).strip()
#     #     print()
#     #     if str(trat_1) == str(trat_2):
#     #       print("é igual depois do tratamento")
#     #     else:
#     #       diverg_desc += 1
#     # z = input("")

#   else:
#     list_dif = list(difference_locations[0])
#     # print(df_1[3],df_1[1] )
#     # print(df_2[3],df_2[1])
#     # print()
#     nao_descarte +=1
#     print(df_1[1])
#     print(df_2[1])
    
#     for it in list_dif:
#       print(df_1[3])
#       print(df_2[3])
#       if it in idx_questoes:
#         print(it)
#         # print(df_1[it])
#         # print(df_2[it])
#         diverg_coleta += 1
#         z = input("")

#   # z= input("")

# print("não descarte:",nao_descarte)
# print("descarte:", descarte)
# # print("a divergencia do descarte é :", diverg_desc)
# print("a possibilidade de erro nos coletados é", len(idx_questoes)*68)
# print("a possibilidade de erro total é", (len(idx_questoes)*68)+43)
# print("o total da divergência é", diverg_coleta)
# tx_diverg = (diverg_coleta*100)/2491
# print("a taxa de divergência do é:",tx_diverg)
